# %% [markdown]
# ## Import the required Python packages:

# %%
import warnings
warnings.simplefilter("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
import gudhi
from persim import PersImage
from persim import PersistenceImager
import ripser
from progressbar import ProgressBar

# %% [markdown]
# ## Data preparation:

# %% [markdown]
# The dataset we use is the NIST 8-Bit Gray Scale Images of Fingerprint Image Groups (FIGS) from [academictorrents](https://academictorrents.com/details/d7e67e86f0f936773f217dbbb9c149c4d98748c6/tech). The NIST Special Database 4 contains 8-bit gray scale images of randomly selected fingerprints. The database was distributed for use in developing and testing automatic fingerprint classification systems on a common set of images. The original zip file contained 4000 fingerprints stored in PNG format (2000 pairs). Each fingerprint is 512 X 512 pixels with 32 rows of white space at the bottom of the fingerprint.

# %%
#preparing data

from PIL import Image, ImageEnhance
img_folder = r'NIST_Database\sd04\png_txt'

t=0.001
#IMG_HEIGHT = 256
#IMG_WIDTH = 256
newsize = (256, 256)

images = []
classes = []
gender_classes = []
for dir1 in os.listdir(img_folder):
    for file in os.listdir(os.path.join(img_folder, dir1)):
        filename = os.fsdecode(file)
        if filename.endswith(".png"):
            image_path= os.path.join(img_folder, dir1,  file)
            img=Image.open(image_path)
            #img=mpimg.imread(image_path)
            #img = (255-img)
            #img = cv2.bitwise_not(img)
            img = img.resize(newsize)
            
            #image brightness enhancer
            enhancer = ImageEnhance.Contrast(img)
            factor = 10 #increase constrast
            img = enhancer.enhance(factor)
            img = cv2.bitwise_not(np.array(img))
            #img=cv2.resize(img, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
            #PIL_image = Image.fromarray(img.astype('uint8'))
            img=img.astype('float32') / 255.
            img[img < t] = 0.
            images.append(img)
            #plt.imshow(img)
        elif filename.endswith(".txt"):
            text_path= os.path.join(img_folder, dir1,  file)
            with open(text_path, 'r') as fh:
                data=fh.readlines()
                #print(data)
                gender_classes.append(data[0].split("Gender:",1)[1][1])
                classes.append(data[1].split("Class:",1)[1][1])
        
images=np.array(images)
classes=np.array(classes)
gender_classes=np.array(gender_classes)

# %%
image_1_path = r'NIST_Database\sd04\png_txt\figs_0\f0001_01.png'
img=mpimg.imread(image_1_path)
plt.imshow(img);

# %%
plt.imshow(images[0]);

# %%
enhancer = ImageEnhance.Contrast(Image.open(image_1_path))
factor = 10 #increase constrast
img = enhancer.enhance(factor)
img
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x1CD78C37CD0>

# %% [markdown]
# #### Why this data set?
#
#  Our goal was to apply TDA methods on new datasets, without any article or tutorial dealing with this dataset. So we searched a large number of datasets on https://www.kaggle.com/datasets and https://datasetsearch.research.google.com/ and randomly chose fingerprints (well, not quite randomly). The motivation is that fingerprints are composed of connected lines, so we assumed that we might be able to get some structures or features that would be extracted by persistence diagrams. After preprocessing the data, we searched for papers that would have already worked on fingerprints and found that SVM is generally the most used method (with different similarity distances) http://eprints.utar.edu.my/3950/1/16ACB02809_FYP.pdf , https://lup.lub.lu.se/luur/download?func=downloadFile&recordOId=8954340&fileOId=8954341 along with CNN used for gender classification https://medium.com/swlh/fingerprint-gender-classification-cnn-8b052a162a93 and other more algorithmic methods that detect loops and singularity points https://www.sciencedirect.com/science/article/abs/pii/0031320395001069 (with a classification accuracy of 85.4% for the five-class problem). But the only paper that interested us was [Graph Representation of Fingerprint Topology] (https://www.semanticscholar.org/paper/Graph-Representation-of-Fingerprint-Topology-%E2%88%97-%C3%96lz-Kropatsch/bb8ed547cc7d3c84111e63365b167672dda715da), the one that shows that a graphical representation is possible for fingerprints, which reassured us to continue.

# %% [markdown]
# ![image.png](fingerprint.png)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
gender_classes_bi= lb.fit_transform(gender_classes)
lb2 = LabelBinarizer()
classes_bi=lb2.fit_transform(classes)

# %% [markdown]
# ## Two-class classification:

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i])
    plt.title(gender_classes[i])
    plt.axis("off")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(images, gender_classes_bi, test_size=0.33, random_state=42)

# %%
xtrain = np.expand_dims(X_train, axis=-1)
xtest = np.expand_dims(X_test, axis=-1)

# %% [markdown]
# Let's start with a convolutional neural network (CNN) We tried different structures (adding different layers and different activation functions) to get a benchmark. Adding too many parameters leads to overfitting.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D
from keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop_after_epochs = 15
model = Sequential()
model.add(Conv2D(128, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_accuracy', patience=early_stop_after_epochs)

# %%
history_test = model.fit(xtrain,y_train,batch_size=64,epochs=50,validation_data=(xtest, y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 42/42 [==============================] - 274s 6s/step - loss: 0.5746 - accuracy: 0.7892 - val_loss: 0.4293 - val_accuracy: 0.8121
# Epoch 2/50
# 42/42 [==============================] - 262s 6s/step - loss: 0.4448 - accuracy: 0.8168 - val_loss: 0.4547 - val_accuracy: 0.8250
# Epoch 3/50
# 42/42 [==============================] - 246s 6s/step - loss: 0.4147 - accuracy: 0.8328 - val_loss: 0.3916 - val_accuracy: 0.8205
# Epoch 4/50
# 42/42 [==============================] - 246s 6s/step - loss: 0.3727 - accuracy: 0.8522 - val_loss: 0.3832 - val_accuracy: 0.8280
# Epoch 5/50
# 42/42 [==============================] - 232s 6s/step - loss: 0.3409 - accuracy: 0.8578 - val_loss: 0.4640 - val_accuracy: 0.8265
# Epoch 6/50
# 42/42 [==============================] - 226s 5s/step - loss: 0.3105 - accuracy: 0.8716 - val_loss: 0.4665 - val_accuracy: 0.8318
# Epoch 7/50
# 42/42 [==============================] - 200s 5s/step - loss: 0.2816 - accuracy: 0.8795 - val_loss: 0.3836 - val_accuracy: 0.8379
# Epoch 8/50
# 42/42 [==============================] - 207s 5s/step - loss: 0.2625 - accuracy: 0.8888 - val_loss: 0.4082 - val_accuracy: 0.8424
# Epoch 9/50
# 42/42 [==============================] - 207s 5s/step - loss: 0.2228 - accuracy: 0.9071 - val_loss: 0.4281 - val_accuracy: 0.8356
# Epoch 10/50
# 42/42 [==============================] - 202s 5s/step - loss: 0.1966 - accuracy: 0.9194 - val_loss: 0.4175 - val_accuracy: 0.8402
# Epoch 11/50
# 42/42 [==============================] - 204s 5s/step - loss: 0.1690 - accuracy: 0.9321 - val_loss: 0.4657 - val_accuracy: 0.8424
# Epoch 12/50
# 42/42 [==============================] - 205s 5s/step - loss: 0.1472 - accuracy: 0.9399 - val_loss: 0.4552 - val_accuracy: 0.8371
# Epoch 13/50
# 42/42 [==============================] - 188s 4s/step - loss: 0.1199 - accuracy: 0.9515 - val_loss: 0.5344 - val_accuracy: 0.8477
# Epoch 14/50
# 42/42 [==============================] - 187s 4s/step - loss: 0.0980 - accuracy: 0.9575 - val_loss: 0.7041 - val_accuracy: 0.8538
# Epoch 15/50
# 42/42 [==============================] - 188s 4s/step - loss: 0.0911 - accuracy: 0.9646 - val_loss: 0.6526 - val_accuracy: 0.8394
# Epoch 16/50
# 42/42 [==============================] - 187s 4s/step - loss: 0.0796 - accuracy: 0.9646 - val_loss: 0.7764 - val_accuracy: 0.8424
# Epoch 17/50
# 42/42 [==============================] - 184s 4s/step - loss: 0.0816 - accuracy: 0.9728 - val_loss: 0.6794 - val_accuracy: 0.8242
# Epoch 18/50
# 42/42 [==============================] - 199s 5s/step - loss: 0.0537 - accuracy: 0.9780 - val_loss: 1.2172 - val_accuracy: 0.8394
# Epoch 19/50
# 42/42 [==============================] - 186s 4s/step - loss: 0.0451 - accuracy: 0.9828 - val_loss: 1.2028 - val_accuracy: 0.8394
# Epoch 20/50
# 42/42 [==============================] - 193s 5s/step - loss: 0.0548 - accuracy: 0.9825 - val_loss: 0.9596 - val_accuracy: 0.8455
# Epoch 21/50
# 42/42 [==============================] - 181s 4s/step - loss: 0.0394 - accuracy: 0.9869 - val_loss: 1.0816 - val_accuracy: 0.8348
# Epoch 22/50
# 42/42 [==============================] - 190s 5s/step - loss: 0.0318 - accuracy: 0.9884 - val_loss: 2.3769 - val_accuracy: 0.8364
# Epoch 23/50
# 42/42 [==============================] - 190s 5s/step - loss: 0.0390 - accuracy: 0.9847 - val_loss: 1.0460 - val_accuracy: 0.8394
# Epoch 24/50
# 42/42 [==============================] - 195s 5s/step - loss: 0.0316 - accuracy: 0.9862 - val_loss: 0.8950 - val_accuracy: 0.8295
# Epoch 25/50
# 42/42 [==============================] - 200s 5s/step - loss: 0.0303 - accuracy: 0.9873 - val_loss: 1.1262 - val_accuracy: 0.8242
# Epoch 26/50
# 42/42 [==============================] - 184s 4s/step - loss: 0.0431 - accuracy: 0.9858 - val_loss: 1.0747 - val_accuracy: 0.8311
# Epoch 27/50
# 42/42 [==============================] - 180s 4s/step - loss: 0.0285 - accuracy: 0.9892 - val_loss: 1.3665 - val_accuracy: 0.8356
# Epoch 28/50
# 42/42 [==============================] - 191s 5s/step - loss: 0.0335 - accuracy: 0.9896 - val_loss: 1.3996 - val_accuracy: 0.8394
# Epoch 29/50
# 42/42 [==============================] - 193s 5s/step - loss: 0.0309 - accuracy: 0.9899 - val_loss: 1.3988 - val_accuracy: 0.8348

# %%
# summarize history for accuracy
plt.plot(history_test.history['accuracy'])
plt.plot(history_test.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_test.history['loss'])
plt.plot(history_test.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D
from keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop_after_epochs = 15
model = Sequential()
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_accuracy', patience=early_stop_after_epochs)

# %%
history = model.fit(xtrain,y_train,batch_size=64,epochs=50,validation_data=(xtest, y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 21/21 [==============================] - 51s 2s/step - loss: 0.5620 - accuracy: 0.7799 - val_loss: 0.4539 - val_accuracy: 0.8212
# Epoch 2/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.4305 - accuracy: 0.8243 - val_loss: 0.4295 - val_accuracy: 0.8182
# Epoch 3/50
# 21/21 [==============================] - 49s 2s/step - loss: 0.4062 - accuracy: 0.8313 - val_loss: 0.4023 - val_accuracy: 0.8258
# Epoch 4/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.3799 - accuracy: 0.8478 - val_loss: 0.4053 - val_accuracy: 0.8205
# Epoch 5/50
# 21/21 [==============================] - 49s 2s/step - loss: 0.3501 - accuracy: 0.8578 - val_loss: 0.4249 - val_accuracy: 0.8265
# Epoch 6/50
# 21/21 [==============================] - 49s 2s/step - loss: 0.3364 - accuracy: 0.8694 - val_loss: 0.3765 - val_accuracy: 0.8386
# Epoch 7/50
# 21/21 [==============================] - 49s 2s/step - loss: 0.2903 - accuracy: 0.8799 - val_loss: 0.3780 - val_accuracy: 0.8455
# Epoch 8/50
# 21/21 [==============================] - 49s 2s/step - loss: 0.2604 - accuracy: 0.8896 - val_loss: 0.4767 - val_accuracy: 0.8311
# Epoch 9/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.2497 - accuracy: 0.8951 - val_loss: 0.4690 - val_accuracy: 0.8379
# Epoch 10/50
# 21/21 [==============================] - 49s 2s/step - loss: 0.2117 - accuracy: 0.9153 - val_loss: 0.3740 - val_accuracy: 0.8265
# Epoch 11/50
# 21/21 [==============================] - 50s 2s/step - loss: 0.1928 - accuracy: 0.9168 - val_loss: 0.4338 - val_accuracy: 0.8492
# Epoch 12/50
# 21/21 [==============================] - 50s 2s/step - loss: 0.1687 - accuracy: 0.9377 - val_loss: 0.4718 - val_accuracy: 0.8470
# Epoch 13/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.1426 - accuracy: 0.9429 - val_loss: 0.3780 - val_accuracy: 0.8333
# Epoch 14/50
# 21/21 [==============================] - 49s 2s/step - loss: 0.1294 - accuracy: 0.9511 - val_loss: 0.4440 - val_accuracy: 0.8492
# Epoch 15/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.1088 - accuracy: 0.9582 - val_loss: 0.4597 - val_accuracy: 0.8515
# Epoch 16/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0926 - accuracy: 0.9698 - val_loss: 0.5680 - val_accuracy: 0.8485
# Epoch 17/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0974 - accuracy: 0.9616 - val_loss: 0.4903 - val_accuracy: 0.8311
# Epoch 18/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0672 - accuracy: 0.9791 - val_loss: 0.5027 - val_accuracy: 0.8417
# Epoch 19/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0545 - accuracy: 0.9847 - val_loss: 0.7778 - val_accuracy: 0.8470
# Epoch 20/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0472 - accuracy: 0.9866 - val_loss: 0.5982 - val_accuracy: 0.8462
# Epoch 21/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0753 - accuracy: 0.9716 - val_loss: 0.5992 - val_accuracy: 0.8515
# Epoch 22/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0280 - accuracy: 0.9922 - val_loss: 0.8306 - val_accuracy: 0.8447
# Epoch 23/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0418 - accuracy: 0.9866 - val_loss: 0.7631 - val_accuracy: 0.8492
# Epoch 24/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0204 - accuracy: 0.9944 - val_loss: 0.7234 - val_accuracy: 0.8417
# Epoch 25/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0736 - accuracy: 0.9731 - val_loss: 0.7543 - val_accuracy: 0.8492
# Epoch 26/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0126 - accuracy: 0.9985 - val_loss: 0.8926 - val_accuracy: 0.8470
# Epoch 27/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0415 - accuracy: 0.9843 - val_loss: 0.7149 - val_accuracy: 0.8417
# Epoch 28/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0158 - accuracy: 0.9966 - val_loss: 0.9564 - val_accuracy: 0.8447
# Epoch 29/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0563 - accuracy: 0.9787 - val_loss: 0.7353 - val_accuracy: 0.8447
# Epoch 30/50
# 21/21 [==============================] - 48s 2s/step - loss: 0.0122 - accuracy: 0.9981 - val_loss: 0.9139 - val_accuracy: 0.8485

# %% [markdown]
# The diverging CNN performs better

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# Now let's use the TDA tools. The most important tool we have is the persistence diagrams, as we saw in the first part of the project. (You can find more information about it in the notebook of part 1)
# In particular, we will use persistence images which are a stable vector representation of persistent homology/persistent diagrams.
# The idea is to convert a persistent diagram into a finite dimensional vector representation which we call a persistence image. Persistence images can be used with vector-based machine learning tools.

# %%
from ripser import Rips
from persim import PersImage
from persim import PersistenceImager

# %%
rips = Rips(maxdim=1, coeff=2)
diagrams = [rips.fit_transform(img) for img in images]
diagrams_h1 = [rips.fit_transform(img)[1] for img in images]
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    rips.plot(diagrams[i], show=False)
    plt.tight_layout()
    plt.title(gender_classes[i])
    #plt.axis("off")

# %%
pimgr = PersistenceImager(pixel_size=0.25)
pimgr.fit(diagrams_h1)
imgs = pimgr.transform(diagrams_h1)

# %%
plt.figure(figsize=(20, 20))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    k=np.random.choice(range(len(imgs)))
    plt.imshow(imgs[k])
    plt.title(gender_classes[k])
    plt.axis("off")

# %%
imgs_array = np.array([img.flatten() for img in imgs])

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs_array,gender_classes_bi , test_size=0.40, random_state=42)

# %%
X_train[0].shape
# Out:
# (1248,)

# %% [markdown]
#  We use vectors of size 1248, we can use other sizes by changing the pixel_size (to 1 for example). We will also try vectors of size 84. And for classification, we will only use logistic regression.

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# The test accuracy is :

# %%
lr.score(X_test, y_test)
# Out:
# 0.804375

# %% [markdown]
# While for the neural network its  :

# %%
np.mean(history.history['val_accuracy'])
# Out:
# 0.8399747530619304

# %%
pimgr2 = PersistenceImager(pixel_size=1)
pimgr2.fit(diagrams_h1)
imgs2 = pimgr2.transform(diagrams_h1)

# %%
plt.figure(figsize=(20, 20))

for i in range(4):
    ax = plt.subplot(2, 2, i + 1)
    k=np.random.choice(range(len(imgs2)))
    plt.imshow(imgs[k])
    plt.title(gender_classes[k])
    plt.axis("off")

# %%
imgs2_array = np.array([img.flatten() for img in imgs2])

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs2_array,gender_classes_bi , test_size=0.40, random_state=42)

# %%
X_train[0].shape
# Out:
# (84,)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.805

# %% [markdown]
# So we get an accuracy of 80.5%, while the neural network it was 83.99%. Although the neural network performs better, it should be noted that we only use vectors of size 84 + simple logistic regression, whereas the neural network, well it's a neural network, uses 256*256 images, so the persistence images have a huge time and memory advantage.

# %% [markdown]
# But, as we will see next. The dataset is unbalanced with respect to gender classification (we won't have this problem with the five-class finger classification). So we will balance the data using the SMOTE synthetic minority oversampling technique. And since we don't want to give the model exactly the same data, we will modify each image by rotating it with a random angle of a normal N(0,3) distribution.

# %%
list(gender_classes).count('M')
# Out:
# 3250

# %%
list(gender_classes).count('F')
# Out:
# 750

# %%
sns.set_theme(style="darkgrid")
df_data=pd.DataFrame({'F':np.array(gender_classes=='F').astype('int32'), 'M':np.array(gender_classes=='M').astype('int32')})


ax = sns.barplot(data=df_data)

# %%
list(gender_classes).count('F')/list(gender_classes).count('M')*100
# Out:
# 23.076923076923077

# %%
print("A classifier that always gives 'M' will ahve an accuracy of {} %".format(100-list(gender_classes).count('F')/list(gender_classes).count('M')*100))
# Out:
# A classifier that always gives 'M' will ahve an accuracy of 76.92307692307692 %

# %%
shape_or = images[0].shape
images_flat = np.array([img.flatten() for img in images ])
from imblearn.over_sampling import SMOTE

oversample = SMOTE()
images_over, gender_classes_bi_over = oversample.fit_resample(images_flat, gender_classes_bi)
images_over = np.array([img.reshape(shape_or) for img in images_over ])

# %%
from PIL import Image

for i in range(len(images_over)):
    img=images_over[i]
    PIL_image = Image.fromarray(img.astype('uint8'))
    angle = np.random.normal(0,3)
    PIL_image = PIL_image.rotate(angle)
    images_over[i]=np.array(PIL_image)

# %%
rips = ripser.Rips(maxdim=1, coeff=2)
diagrams_ = [rips.fit_transform(img) for img in images_over]
diagrams_h1_ = [diag[1] for diag in diagrams_]
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
pimgr_ = PersistenceImager(pixel_size=0.25)
pimgr_.fit(diagrams_h1_)
imgs_ = pimgr_.transform(diagrams_h1_)
imgs_array= np.array([img.flatten() for img in imgs_ ])

# %% [markdown]
# With logistic regression

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs_array,gender_classes_bi_over , test_size=0.40, random_state=42)
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.806923076923077

# %% [markdown]
# The accuracy didnt really change that much. Now let's see with the neural network.

# %%
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(images_over, gender_classes_bi_over, test_size=0.3, random_state=69)
xtrain2 = np.expand_dims(X_train2, axis=-1)
xtest2 = np.expand_dims(X_test2, axis=-1)
X_train, X_test, y_train, y_test = train_test_split(imgs_array, gender_classes_bi_over, test_size=0.3, random_state=69)
xtrain = np.expand_dims(X_train, axis=-1)
xtest = np.expand_dims(X_test, axis=-1)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D
from keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
early_stop_after_epochs = 10
model = Sequential()
model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Conv2D(128, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
 
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_accuracy', patience=early_stop_after_epochs)

# %%
history = model.fit(xtrain2,y_train,batch_size=64,epochs=50,validation_data=(xtest2, y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 72/72 [==============================] - 117s 2s/step - loss: 0.6335 - accuracy: 0.7536 - val_loss: 0.4079 - val_accuracy: 0.8215
# Epoch 2/50
# 72/72 [==============================] - 115s 2s/step - loss: 0.4162 - accuracy: 0.8281 - val_loss: 0.8992 - val_accuracy: 0.6882
# Epoch 3/50
# 72/72 [==============================] - 115s 2s/step - loss: 0.3383 - accuracy: 0.8626 - val_loss: 0.4435 - val_accuracy: 0.8246
# Epoch 4/50
# 72/72 [==============================] - 115s 2s/step - loss: 0.2518 - accuracy: 0.8996 - val_loss: 0.4181 - val_accuracy: 0.8246
# Epoch 5/50
# 72/72 [==============================] - 116s 2s/step - loss: 0.1777 - accuracy: 0.9327 - val_loss: 0.3871 - val_accuracy: 0.8713
# Epoch 6/50
# 72/72 [==============================] - 119s 2s/step - loss: 0.1085 - accuracy: 0.9596 - val_loss: 0.3847 - val_accuracy: 0.8836
# Epoch 7/50
# 72/72 [==============================] - 119s 2s/step - loss: 0.0668 - accuracy: 0.9756 - val_loss: 0.4616 - val_accuracy: 0.8718
# Epoch 8/50
# 72/72 [==============================] - 119s 2s/step - loss: 0.0524 - accuracy: 0.9820 - val_loss: 0.7176 - val_accuracy: 0.8708
# Epoch 9/50
# 72/72 [==============================] - 119s 2s/step - loss: 0.0243 - accuracy: 0.9921 - val_loss: 1.2909 - val_accuracy: 0.8154
# Epoch 10/50
# 72/72 [==============================] - 119s 2s/step - loss: 0.1093 - accuracy: 0.9842 - val_loss: 0.5917 - val_accuracy: 0.8697
# Epoch 11/50
# 72/72 [==============================] - 109s 2s/step - loss: 0.0353 - accuracy: 0.9916 - val_loss: 0.6909 - val_accuracy: 0.8769
# Epoch 12/50
# 72/72 [==============================] - 109s 2s/step - loss: 0.0253 - accuracy: 0.9930 - val_loss: 0.7234 - val_accuracy: 0.8831
# Epoch 13/50
# 72/72 [==============================] - 109s 2s/step - loss: 0.0324 - accuracy: 0.9941 - val_loss: 0.8684 - val_accuracy: 0.8856
# Epoch 14/50
# 72/72 [==============================] - 110s 2s/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 1.1104 - val_accuracy: 0.8738
# Epoch 15/50
# 72/72 [==============================] - 110s 2s/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 1.0165 - val_accuracy: 0.8718
# Epoch 16/50
# 72/72 [==============================] - 110s 2s/step - loss: 0.0317 - accuracy: 0.9932 - val_loss: 0.8490 - val_accuracy: 0.8646
# Epoch 17/50
# 72/72 [==============================] - 110s 2s/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.9976 - val_accuracy: 0.8846
# Epoch 18/50
# 72/72 [==============================] - 110s 2s/step - loss: 0.0718 - accuracy: 0.9936 - val_loss: 1.0044 - val_accuracy: 0.8805
# Epoch 19/50
# 72/72 [==============================] - 110s 2s/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 1.0970 - val_accuracy: 0.8646
# Epoch 20/50
# 72/72 [==============================] - 109s 2s/step - loss: 3.0949e-04 - accuracy: 1.0000 - val_loss: 1.4622 - val_accuracy: 0.8795
# Epoch 21/50
# 72/72 [==============================] - 108s 2s/step - loss: 0.0226 - accuracy: 0.9974 - val_loss: 1.4344 - val_accuracy: 0.8764
# Epoch 22/50
# 72/72 [==============================] - 109s 2s/step - loss: 0.0278 - accuracy: 0.9947 - val_loss: 1.0956 - val_accuracy: 0.8769
# Epoch 23/50
# 72/72 [==============================] - 108s 2s/step - loss: 0.0371 - accuracy: 0.9934 - val_loss: 0.8061 - val_accuracy: 0.8795

# %%
plot_model(model,show_shapes=True, show_layer_names=True)

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# An other possible use of persistence diagrams or persistence images is using them for feature augmentation. We create a neural network that takes as input both the image and its corresponding persistence image.

# %%
from tensorflow.keras.layers import concatenate, Input ,Flatten,Dense,Dropout
from tensorflow.keras.models import Model
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D

# %%
input_images = Input(shape=(X_train2[0].shape[0], X_train2[0].shape[1],1,))
x = Conv2D(kernel_size=(4,4), filters=32, activation='selu')(input_images)
x = MaxPool2D(5,5)(x)
x = Conv2D(filters=64,kernel_size = (3,3),activation='selu')(x)
x = MaxPool2D(2,2)(x)
x = Conv2D(filters=128,kernel_size = (3,3),activation='relu')(x)
x = MaxPool2D(2,2)(x)
x = Flatten()(x)
x = Dense(64,activation='relu')(x)
x = Model(inputs=input_images, outputs=x)

#second model #two options (images or not)
input_features = Input(shape=(X_train[0].shape[0],))
y = Dense(X_train[0].shape[0],activation='relu')(input_features)
y = Dense(64,activation='relu')(y)
y = Model(inputs=input_features, outputs=y)

# combine the output of the two branches
combined = concatenate([x.output, y.output])
# apply a FC layer and then a regression prediction on the
# combined outputs




z = Dense(32,activation=tf.keras.layers.LeakyReLU(alpha=0.3))(combined)
z = Dropout(0.2)(z)
z= Dense(1,activation = 'sigmoid')(z)
model_2 = Model(inputs=[x.input, y.input], outputs=z)

# %%
model_2.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
from keras.utils.vis_utils import plot_model
plot_model(model_2, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
history_2=model_2.fit( x=[xtrain2, xtrain], y=y_train, validation_data=([xtest2, xtest], y_test), epochs=32, batch_size=32)
# Out:
# Epoch 1/32
# 143/143 [==============================] - 74s 498ms/step - loss: 0.5062 - accuracy: 0.7703 - val_loss: 0.4903 - val_accuracy: 0.7723
# Epoch 2/32
# 143/143 [==============================] - 74s 519ms/step - loss: 0.3994 - accuracy: 0.8341 - val_loss: 0.3405 - val_accuracy: 0.8564
# Epoch 3/32
# 143/143 [==============================] - 72s 506ms/step - loss: 0.3459 - accuracy: 0.8598 - val_loss: 0.4738 - val_accuracy: 0.7892
# Epoch 4/32
# 143/143 [==============================] - 74s 516ms/step - loss: 0.3054 - accuracy: 0.8778 - val_loss: 0.3263 - val_accuracy: 0.8677
# Epoch 5/32
# 143/143 [==============================] - 73s 510ms/step - loss: 0.2571 - accuracy: 0.8996 - val_loss: 0.2935 - val_accuracy: 0.8923
# Epoch 6/32
# 143/143 [==============================] - 74s 518ms/step - loss: 0.2144 - accuracy: 0.9130 - val_loss: 0.2895 - val_accuracy: 0.9021
# Epoch 7/32
# 143/143 [==============================] - 74s 518ms/step - loss: 0.1780 - accuracy: 0.9305 - val_loss: 0.3071 - val_accuracy: 0.9010
# Epoch 8/32
# 143/143 [==============================] - 71s 498ms/step - loss: 0.1482 - accuracy: 0.9455 - val_loss: 0.3044 - val_accuracy: 0.8944
# Epoch 9/32
# 143/143 [==============================] - 72s 504ms/step - loss: 0.1171 - accuracy: 0.9554 - val_loss: 0.4135 - val_accuracy: 0.9046
# Epoch 10/32
# 143/143 [==============================] - 74s 517ms/step - loss: 0.0935 - accuracy: 0.9657 - val_loss: 0.4635 - val_accuracy: 0.9031
# Epoch 11/32
# 143/143 [==============================] - 75s 522ms/step - loss: 0.0751 - accuracy: 0.9747 - val_loss: 0.5498 - val_accuracy: 0.8964
# Epoch 12/32
# 143/143 [==============================] - 74s 517ms/step - loss: 0.0536 - accuracy: 0.9802 - val_loss: 0.5335 - val_accuracy: 0.9010
# Epoch 13/32
# 143/143 [==============================] - 72s 506ms/step - loss: 0.0451 - accuracy: 0.9851 - val_loss: 0.6144 - val_accuracy: 0.8882
# Epoch 14/32
# 143/143 [==============================] - 74s 515ms/step - loss: 0.0596 - accuracy: 0.9857 - val_loss: 0.6324 - val_accuracy: 0.8815
# Epoch 15/32
# 143/143 [==============================] - 74s 515ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.8510 - val_accuracy: 0.8908
# Epoch 16/32
# 143/143 [==============================] - 79s 550ms/step - loss: 0.0337 - accuracy: 0.9923 - val_loss: 1.0145 - val_accuracy: 0.9154
# Epoch 17/32
# 143/143 [==============================] - 76s 530ms/step - loss: 0.0311 - accuracy: 0.9919 - val_loss: 0.7663 - val_accuracy: 0.9046
# Epoch 18/32
# 143/143 [==============================] - 76s 535ms/step - loss: 0.0358 - accuracy: 0.9910 - val_loss: 0.8045 - val_accuracy: 0.8974
# Epoch 19/32
# 143/143 [==============================] - 74s 519ms/step - loss: 0.0325 - accuracy: 0.9949 - val_loss: 0.9898 - val_accuracy: 0.8979
# Epoch 20/32
# 143/143 [==============================] - 73s 512ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 1.0409 - val_accuracy: 0.9077
# Epoch 21/32
# 143/143 [==============================] - 74s 520ms/step - loss: 0.0298 - accuracy: 0.9921 - val_loss: 0.9489 - val_accuracy: 0.9005
# Epoch 22/32
# 143/143 [==============================] - 73s 512ms/step - loss: 0.0218 - accuracy: 0.9943 - val_loss: 1.0997 - val_accuracy: 0.9072
# Epoch 23/32
# 143/143 [==============================] - 73s 512ms/step - loss: 0.0187 - accuracy: 0.9960 - val_loss: 0.9346 - val_accuracy: 0.9097
# Epoch 24/32
# 143/143 [==============================] - 76s 529ms/step - loss: 0.0275 - accuracy: 0.9958 - val_loss: 1.0016 - val_accuracy: 0.8995
# Epoch 25/32
# 143/143 [==============================] - 74s 516ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 1.2422 - val_accuracy: 0.9144
# Epoch 26/32
# 143/143 [==============================] - 75s 524ms/step - loss: 0.0454 - accuracy: 0.9949 - val_loss: 1.0835 - val_accuracy: 0.9056
# Epoch 27/32
# 143/143 [==============================] - 74s 516ms/step - loss: 0.0143 - accuracy: 0.9963 - val_loss: 1.3027 - val_accuracy: 0.9097
# Epoch 28/32
# 143/143 [==============================] - 75s 525ms/step - loss: 0.0333 - accuracy: 0.9943 - val_loss: 1.1336 - val_accuracy: 0.8974
# Epoch 29/32
# 143/143 [==============================] - 76s 530ms/step - loss: 0.0121 - accuracy: 0.9976 - val_loss: 1.0232 - val_accuracy: 0.9000
# Epoch 30/32
# 143/143 [==============================] - 75s 525ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 1.3242 - val_accuracy: 0.8949
# Epoch 31/32
# 143/143 [==============================] - 75s 525ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 1.3718 - val_accuracy: 0.9097
# Epoch 32/32
# 143/143 [==============================] - 77s 539ms/step - loss: 0.0148 - accuracy: 0.9985 - val_loss: 1.4590 - val_accuracy: 0.8923

# %%
histories_loss = [history.history['val_loss'],history_2.history['val_loss']]

sns.boxplot(data= pd.DataFrame (list(map(list, zip(*histories_loss))), columns = ['Validation loss CNN','Validation loss of persistence model']),showfliers=False)
# Out:
# <AxesSubplot:>

# %%
histories_accuracy= [history.history['val_accuracy'][5:],history_2.history['val_accuracy'][5:]]
sns.boxplot(data= pd.DataFrame (list(map(list, zip(*histories_accuracy))), columns = ['Validation accuracy CNN','Validation accuracyof persistence model']),showfliers=False)
# Out:
# <AxesSubplot:>

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'],label = 'CNN accuracy ')
plt.plot(history.history['val_accuracy'],label = 'CNN validation accuracy ')
plt.plot(history_2.history['accuracy'],label = 'CNN + features accuracy ')
plt.plot(history_2.history['val_accuracy'],label = 'CNN + features validation accuracy ')
                    
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'],label = 'CNN loss ')
plt.plot(history.history['val_loss'],label = 'CNN val_loss ')
plt.plot(history_2.history['loss'],label = 'CNN+ features loss ')
plt.plot(history_2.history['val_loss'],label = 'CNN+ features val_loss ')

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %%
#X_train, X_test, y_train, y_test = train_test_split([img.flatten() for img in imgstrain_array],y_train, test_size=0.3, random_state=42)
from sklearn.metrics import accuracy_score

import lightgbm as lgb
lgbc = lgb.LGBMClassifier()
lgbc.fit(X_train, y_train)
y_pred=clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred) 
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 81.38%

# %%
from xgboost import XGBClassifier

XGBC = XGBClassifier() 
XGBC.fit(X_train, y_train)
y_pred = XGBC.predict(X_test) 
accuracy = accuracy_score(y_test, y_pred) 
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# [06:18:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 80.26%

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.8056410256410257

# %% [markdown]
# ## Classification into five classes

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i])
    plt.title(classes[i])
    plt.axis("off")

# %%
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(images, classes_bi, test_size=0.33, random_state=42)

# %%
xtrain2 = np.expand_dims(X_train2, axis=-1)
xtest2 = np.expand_dims(X_test2, axis=-1)

# %%
from tensorflow.keras.layers import concatenate, Input ,Flatten,Dense,Dropout
from tensorflow.keras.models import Model
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D

# %%
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D
# Creating a Sequential model
model2= Sequential()
model2.add(Conv2D(kernel_size=(10,10), filters=32, activation='selu'))#, input_shape=(100,100,1,)))
model2.add(MaxPool2D(5,5))
model2.add(Conv2D(filters=30,kernel_size = (3,3),activation='selu')) #activation='tanh'
model2.add(MaxPool2D(2,2))
model2.add(Conv2D(filters=30,kernel_size = (3,3),activation='relu'))
model2.add(MaxPool2D(2,2))
model2.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))

model2.add(Flatten())

model2.add(Dense(30,activation='selu'))
model2.add(Dropout(0.2))
model2.add(Dense(15,activation='selu'))
model2.add(Dense(5,activation = 'softmax')) #sigmoid
    
model2.compile(loss='categorical_crossentropy', metrics=['acc'],optimizer='adam')

# %%
history2=model2.fit(xtrain2,y_train2,batch_size=32,epochs=50,validation_data=(xtest2, y_test2))
#val_acc: 0.6129
# Out:
# Epoch 1/50
# 84/84 [==============================] - 93s 1s/step - loss: 1.4649 - acc: 0.3377 - val_loss: 1.2022 - val_acc: 0.4561
# Epoch 2/50
# 84/84 [==============================] - 92s 1s/step - loss: 1.0384 - acc: 0.5634 - val_loss: 1.0206 - val_acc: 0.5576
# Epoch 3/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.9146 - acc: 0.6250 - val_loss: 0.8856 - val_acc: 0.6182
# Epoch 4/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.8840 - acc: 0.6433 - val_loss: 0.8518 - val_acc: 0.6523
# Epoch 5/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.8077 - acc: 0.6765 - val_loss: 0.7641 - val_acc: 0.6735
# Epoch 6/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.7497 - acc: 0.7067 - val_loss: 0.8132 - val_acc: 0.6735
# Epoch 7/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.7151 - acc: 0.7146 - val_loss: 0.7441 - val_acc: 0.6894
# Epoch 8/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.6275 - acc: 0.7545 - val_loss: 0.7741 - val_acc: 0.6864
# Epoch 9/50
# 84/84 [==============================] - 90s 1s/step - loss: 0.6118 - acc: 0.7642 - val_loss: 0.7129 - val_acc: 0.7106
# Epoch 10/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.5473 - acc: 0.7896 - val_loss: 0.6864 - val_acc: 0.7273
# Epoch 11/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.5181 - acc: 0.8157 - val_loss: 0.7056 - val_acc: 0.7227
# Epoch 12/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.4338 - acc: 0.8347 - val_loss: 0.6492 - val_acc: 0.7477
# Epoch 13/50
# 84/84 [==============================] - 90s 1s/step - loss: 0.3552 - acc: 0.8672 - val_loss: 0.7513 - val_acc: 0.7394
# Epoch 14/50
# 84/84 [==============================] - 92s 1s/step - loss: 0.3364 - acc: 0.8668 - val_loss: 0.7679 - val_acc: 0.7288
# Epoch 15/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.3188 - acc: 0.8784 - val_loss: 0.8395 - val_acc: 0.7220
# Epoch 16/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.2636 - acc: 0.9041 - val_loss: 0.8595 - val_acc: 0.7159
# Epoch 17/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.2064 - acc: 0.9246 - val_loss: 0.9223 - val_acc: 0.7167
# Epoch 18/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.2034 - acc: 0.9272 - val_loss: 0.9739 - val_acc: 0.7091
# Epoch 19/50
# 84/84 [==============================] - 94s 1s/step - loss: 0.1798 - acc: 0.9373 - val_loss: 0.9393 - val_acc: 0.7114
# Epoch 20/50
# 84/84 [==============================] - 100s 1s/step - loss: 0.1467 - acc: 0.9493 - val_loss: 0.9886 - val_acc: 0.7273
# Epoch 21/50
# 84/84 [==============================] - 96s 1s/step - loss: 0.1063 - acc: 0.9593 - val_loss: 1.0530 - val_acc: 0.7182
# Epoch 22/50
# 84/84 [==============================] - 96s 1s/step - loss: 0.1044 - acc: 0.9604 - val_loss: 1.1526 - val_acc: 0.7136
# Epoch 23/50
# 84/84 [==============================] - 97s 1s/step - loss: 0.0997 - acc: 0.9653 - val_loss: 1.1518 - val_acc: 0.7288
# Epoch 24/50
# 84/84 [==============================] - 96s 1s/step - loss: 0.0816 - acc: 0.9746 - val_loss: 1.2386 - val_acc: 0.7182
# Epoch 25/50
# 84/84 [==============================] - 96s 1s/step - loss: 0.1255 - acc: 0.9556 - val_loss: 1.2834 - val_acc: 0.6939
# Epoch 26/50
# 84/84 [==============================] - 93s 1s/step - loss: 0.1826 - acc: 0.9328 - val_loss: 1.2876 - val_acc: 0.7061
# Epoch 27/50
# 84/84 [==============================] - 95s 1s/step - loss: 0.1309 - acc: 0.9493 - val_loss: 1.3205 - val_acc: 0.6932
# Epoch 28/50
# 84/84 [==============================] - 93s 1s/step - loss: 0.0935 - acc: 0.9694 - val_loss: 1.2668 - val_acc: 0.7152
# Epoch 29/50
# 84/84 [==============================] - 93s 1s/step - loss: 0.0377 - acc: 0.9877 - val_loss: 1.2781 - val_acc: 0.7273
# Epoch 30/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.0329 - acc: 0.9903 - val_loss: 1.3430 - val_acc: 0.7197
# Epoch 31/50
# 84/84 [==============================] - 92s 1s/step - loss: 0.0247 - acc: 0.9933 - val_loss: 1.3058 - val_acc: 0.7364
# Epoch 32/50
# 84/84 [==============================] - 92s 1s/step - loss: 0.0222 - acc: 0.9937 - val_loss: 1.3711 - val_acc: 0.7371
# Epoch 33/50
# 84/84 [==============================] - 93s 1s/step - loss: 0.0280 - acc: 0.9914 - val_loss: 1.4515 - val_acc: 0.7235
# Epoch 34/50
# 84/84 [==============================] - 93s 1s/step - loss: 0.0641 - acc: 0.9776 - val_loss: 1.4749 - val_acc: 0.7053
# Epoch 35/50
# 84/84 [==============================] - 94s 1s/step - loss: 0.0845 - acc: 0.9675 - val_loss: 1.6740 - val_acc: 0.6818
# Epoch 36/50
# 84/84 [==============================] - 93s 1s/step - loss: 0.0987 - acc: 0.9660 - val_loss: 1.5906 - val_acc: 0.7000
# Epoch 37/50
# 84/84 [==============================] - 93s 1s/step - loss: 0.0637 - acc: 0.9799 - val_loss: 1.4967 - val_acc: 0.7061
# Epoch 38/50
# 84/84 [==============================] - 92s 1s/step - loss: 0.0664 - acc: 0.9769 - val_loss: 1.5917 - val_acc: 0.7091
# Epoch 39/50
# 84/84 [==============================] - 91s 1s/step - loss: 0.1179 - acc: 0.9541 - val_loss: 1.7115 - val_acc: 0.7045
# Epoch 40/50
# 84/84 [==============================] - 92s 1s/step - loss: 0.0914 - acc: 0.9623 - val_loss: 1.7323 - val_acc: 0.7076
# Epoch 41/50
# 84/84 [==============================] - 99s 1s/step - loss: 0.0708 - acc: 0.9765 - val_loss: 1.5658 - val_acc: 0.7273
# Epoch 42/50
# 84/84 [==============================] - 99s 1s/step - loss: 0.0435 - acc: 0.9858 - val_loss: 1.7031 - val_acc: 0.6955
# Epoch 43/50
# 84/84 [==============================] - 98s 1s/step - loss: 0.0474 - acc: 0.9813 - val_loss: 1.6012 - val_acc: 0.7341
# Epoch 44/50
# 84/84 [==============================] - 99s 1s/step - loss: 0.0251 - acc: 0.9903 - val_loss: 1.7239 - val_acc: 0.7129
# Epoch 45/50
# 84/84 [==============================] - 94s 1s/step - loss: 0.0383 - acc: 0.9881 - val_loss: 1.6859 - val_acc: 0.7205
# Epoch 46/50
# 84/84 [==============================] - 98s 1s/step - loss: 0.0303 - acc: 0.9888 - val_loss: 1.6787 - val_acc: 0.7129
# Epoch 47/50
# 84/84 [==============================] - 96s 1s/step - loss: 0.0158 - acc: 0.9959 - val_loss: 1.7042 - val_acc: 0.7068
# Epoch 48/50
# 84/84 [==============================] - 94s 1s/step - loss: 0.0135 - acc: 0.9951 - val_loss: 1.7098 - val_acc: 0.7159
# Epoch 49/50
# 84/84 [==============================] - 98s 1s/step - loss: 0.0119 - acc: 0.9966 - val_loss: 1.9018 - val_acc: 0.7174
# Epoch 50/50
# 84/84 [==============================] - 98s 1s/step - loss: 0.0570 - acc: 0.9840 - val_loss: 2.0046 - val_acc: 0.6727

# %%
# summarize history for accuracy
plt.plot(history2.history['acc'])
plt.plot(history2.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    rips.plot(diagrams[i], show=False)
    plt.tight_layout()
    plt.title(classes[i])
    #plt.axis("off")

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(imgs[i])
    plt.title(classes[i])
    plt.axis("off")

# %%
rips = ripser.Rips(maxdim=1, coeff=2)
diagrams_5 = [rips.fit_transform(img) for img in images]
diagrams_h1_5 = [diag[1] for diag in diagrams_5]
pimgr_5 = PersistenceImager(pixel_size=0.25)
pimgr_5.fit(diagrams_h1_5)
imgs_5 = pimgr_5.transform(diagrams_h1_5)
imgs_array_5c= np.array([img.flatten() for img in imgs_5 ])
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(images, classes_bi, test_size=0.3, random_state=69)
xtrain2 = np.expand_dims(X_train2, axis=-1)
xtest2 = np.expand_dims(X_test2, axis=-1)
X_train, X_test, y_train, y_test = train_test_split(imgs_array_5c, classes_bi, test_size=0.3, random_state=69)
xtrain = np.expand_dims(X_train, axis=-1)
xtest = np.expand_dims(X_test, axis=-1)

# %%
from tensorflow.keras.layers import concatenate, Input ,Flatten,Dense,Dropout
from tensorflow.keras.models import Model

# %%
X_train[0].shape
# Out:
# (1248,)

# %%
X_train2[0].shape
# Out:
# (256, 256)

# %%
input_images = Input(shape=(X_train2[0].shape[0], X_train2[0].shape[1],1,))
x = Conv2D(kernel_size=(10,10), filters=32, activation='selu')(input_images)
x = MaxPool2D(5,5)(x)
x = Conv2D(filters=30,kernel_size = (3,3),activation='selu')(x)
x = MaxPool2D(2,2)(x)
x = Conv2D(filters=30,kernel_size = (3,3),activation='relu')(x)
x = MaxPool2D(2,2)(x)
x = Conv2D(filters=30,kernel_size = (3,3),activation='tanh')(x)
x = Flatten()(x)
x = Model(inputs=input_images, outputs=x)

#second model #two options (images or not)
input_features = Input(shape=(X_train[0].shape[0],))
y = Dense(X_train[0].shape[0],activation='relu')(input_features)
y = Dense(10,activation='relu')(y)
y = Model(inputs=input_features, outputs=y)

# combine the output of the two branches
combined = concatenate([x.output, y.output])
# apply a FC layer and then a regression prediction on the
# combined outputs
z = Dense(20,activation='selu')(combined)
z = Dropout(0.2)(z)
z = Dense(10,activation=tf.keras.layers.LeakyReLU(alpha=0.3))(z)
z= Dense(5,activation = 'softmax')(z)
model3 = Model(inputs=[x.input, y.input], outputs=z)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model3, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model3.compile(loss='categorical_crossentropy', metrics=['acc'],optimizer='adam')

# %%
history3=model3.fit( x=[xtrain2, xtrain], y=y_train, validation_data=([xtest2, xtest], y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 88/88 [==============================] - 91s 1s/step - loss: 1.6143 - acc: 0.2304 - val_loss: 1.5822 - val_acc: 0.2925
# Epoch 2/50
# 88/88 [==============================] - 90s 1s/step - loss: 1.5746 - acc: 0.2643 - val_loss: 1.5227 - val_acc: 0.3092
# Epoch 3/50
# 88/88 [==============================] - 89s 1s/step - loss: 1.3288 - acc: 0.4371 - val_loss: 1.1082 - val_acc: 0.5383
# Epoch 4/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.9825 - acc: 0.5936 - val_loss: 0.9007 - val_acc: 0.6300
# Epoch 5/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.8580 - acc: 0.6536 - val_loss: 0.8362 - val_acc: 0.6567
# Epoch 6/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.8030 - acc: 0.6646 - val_loss: 0.8199 - val_acc: 0.6750
# Epoch 7/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.7052 - acc: 0.7139 - val_loss: 0.7684 - val_acc: 0.7083
# Epoch 8/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.6554 - acc: 0.7350 - val_loss: 1.0299 - val_acc: 0.6425
# Epoch 9/50
# 88/88 [==============================] - 91s 1s/step - loss: 0.6288 - acc: 0.7475 - val_loss: 0.7654 - val_acc: 0.6917
# Epoch 10/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.6187 - acc: 0.7525 - val_loss: 0.6986 - val_acc: 0.7333
# Epoch 11/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.5402 - acc: 0.7811 - val_loss: 0.6825 - val_acc: 0.7275
# Epoch 12/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.5370 - acc: 0.7786 - val_loss: 0.7012 - val_acc: 0.7208
# Epoch 13/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.5036 - acc: 0.7986 - val_loss: 0.6599 - val_acc: 0.7292
# Epoch 14/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.4433 - acc: 0.8296 - val_loss: 0.6629 - val_acc: 0.7400
# Epoch 15/50
# 88/88 [==============================] - 91s 1s/step - loss: 0.4013 - acc: 0.8371 - val_loss: 0.7652 - val_acc: 0.6975
# Epoch 16/50
# 88/88 [==============================] - 91s 1s/step - loss: 0.4007 - acc: 0.8457 - val_loss: 0.7116 - val_acc: 0.7517
# Epoch 17/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.3632 - acc: 0.8607 - val_loss: 0.6933 - val_acc: 0.7533
# Epoch 18/50
# 88/88 [==============================] - 90s 1s/step - loss: 0.3257 - acc: 0.8775 - val_loss: 0.6723 - val_acc: 0.7550
# Epoch 19/50
# 88/88 [==============================] - 92s 1s/step - loss: 0.3110 - acc: 0.8857 - val_loss: 0.7181 - val_acc: 0.7375
# Epoch 20/50
# 88/88 [==============================] - 104s 1s/step - loss: 0.3167 - acc: 0.8768 - val_loss: 0.8262 - val_acc: 0.7208
# Epoch 21/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.2430 - acc: 0.9139 - val_loss: 0.8535 - val_acc: 0.7250
# Epoch 22/50
# 88/88 [==============================] - 100s 1s/step - loss: 0.2392 - acc: 0.9086 - val_loss: 0.7875 - val_acc: 0.7492
# Epoch 23/50
# 88/88 [==============================] - 104s 1s/step - loss: 0.2258 - acc: 0.9139 - val_loss: 0.8084 - val_acc: 0.7550
# Epoch 24/50
# 88/88 [==============================] - 113s 1s/step - loss: 0.1709 - acc: 0.9404 - val_loss: 0.8347 - val_acc: 0.7358
# Epoch 25/50
# 88/88 [==============================] - 106s 1s/step - loss: 0.1963 - acc: 0.9275 - val_loss: 0.8851 - val_acc: 0.7317
# Epoch 26/50
# 88/88 [==============================] - 104s 1s/step - loss: 0.1891 - acc: 0.9357 - val_loss: 0.9650 - val_acc: 0.7225
# Epoch 27/50
# 88/88 [==============================] - 103s 1s/step - loss: 0.1572 - acc: 0.9429 - val_loss: 0.9842 - val_acc: 0.7400
# Epoch 28/50
# 88/88 [==============================] - 105s 1s/step - loss: 0.1316 - acc: 0.9554 - val_loss: 0.9665 - val_acc: 0.7317
# Epoch 29/50
# 88/88 [==============================] - 108s 1s/step - loss: 0.1080 - acc: 0.9646 - val_loss: 1.0359 - val_acc: 0.7383
# Epoch 30/50
# 88/88 [==============================] - 99s 1s/step - loss: 0.0970 - acc: 0.9639 - val_loss: 1.0859 - val_acc: 0.7358
# Epoch 31/50
# 88/88 [==============================] - 100s 1s/step - loss: 0.1075 - acc: 0.9621 - val_loss: 1.1208 - val_acc: 0.7317
# Epoch 32/50
# 88/88 [==============================] - 104s 1s/step - loss: 0.1056 - acc: 0.9621 - val_loss: 1.0128 - val_acc: 0.7483
# Epoch 33/50
# 88/88 [==============================] - 106s 1s/step - loss: 0.1075 - acc: 0.9632 - val_loss: 1.2568 - val_acc: 0.7058
# Epoch 34/50
# 88/88 [==============================] - 105s 1s/step - loss: 0.1914 - acc: 0.9318 - val_loss: 1.0500 - val_acc: 0.7567
# Epoch 35/50
# 88/88 [==============================] - 105s 1s/step - loss: 0.0808 - acc: 0.9757 - val_loss: 1.0809 - val_acc: 0.7392
# Epoch 36/50
# 88/88 [==============================] - 107s 1s/step - loss: 0.0628 - acc: 0.9800 - val_loss: 1.1848 - val_acc: 0.7475
# Epoch 37/50
# 88/88 [==============================] - 106s 1s/step - loss: 0.1143 - acc: 0.9575 - val_loss: 1.3581 - val_acc: 0.7225
# Epoch 38/50
# 88/88 [==============================] - 107s 1s/step - loss: 0.0766 - acc: 0.9789 - val_loss: 1.2581 - val_acc: 0.7417
# Epoch 39/50
# 88/88 [==============================] - 107s 1s/step - loss: 0.0602 - acc: 0.9804 - val_loss: 1.2389 - val_acc: 0.7417
# Epoch 40/50
# 88/88 [==============================] - 99s 1s/step - loss: 0.0472 - acc: 0.9836 - val_loss: 1.1758 - val_acc: 0.7525
# Epoch 41/50
# 88/88 [==============================] - 98s 1s/step - loss: 0.0638 - acc: 0.9800 - val_loss: 1.2708 - val_acc: 0.7308
# Epoch 42/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.0695 - acc: 0.9768 - val_loss: 1.2979 - val_acc: 0.7517
# Epoch 43/50
# 88/88 [==============================] - 103s 1s/step - loss: 0.0719 - acc: 0.9761 - val_loss: 1.3060 - val_acc: 0.7408
# Epoch 44/50
# 88/88 [==============================] - 100s 1s/step - loss: 0.0989 - acc: 0.9682 - val_loss: 1.2156 - val_acc: 0.7417
# Epoch 45/50
# 88/88 [==============================] - 100s 1s/step - loss: 0.1902 - acc: 0.9339 - val_loss: 1.4255 - val_acc: 0.6975
# Epoch 46/50
# 88/88 [==============================] - 104s 1s/step - loss: 0.1592 - acc: 0.9400 - val_loss: 1.2306 - val_acc: 0.7317
# Epoch 47/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.0972 - acc: 0.9675 - val_loss: 1.1350 - val_acc: 0.7608
# Epoch 48/50
# 88/88 [==============================] - 98s 1s/step - loss: 0.0529 - acc: 0.9829 - val_loss: 1.2192 - val_acc: 0.7625
# Epoch 49/50
# 88/88 [==============================] - 97s 1s/step - loss: 0.0456 - acc: 0.9846 - val_loss: 1.2797 - val_acc: 0.7483
# Epoch 50/50
# 88/88 [==============================] - 99s 1s/step - loss: 0.0369 - acc: 0.9889 - val_loss: 1.3514 - val_acc: 0.7458

# %%
sns.boxplot(data=[history2.history['val_acc'],history3.history['val_acc']],showfliers=False)
# Out:
# <AxesSubplot:>

# %%
plt.plot(history2.history['val_acc'],label = 'CNN validation accuracy ')
plt.plot(history3.history['val_acc'],label = 'CNN + features validation accuracy ')
plt.ylim(0.6,0.8)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history2.history['acc'],label = 'CNN accuracy ')
plt.plot(history2.history['val_acc'],label = 'CNN validation accuracy ')
plt.plot(history3.history['acc'],label = 'CNN + features accuracy ')
plt.plot(history3.history['val_acc'],label = 'CNN + features validation accuracy ')
                    
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()
# summarize history for loss
plt.plot(history2.history['loss'],label = 'CNN loss ')
plt.plot(history2.history['val_loss'],label = 'CNN val_loss ')
plt.plot(history3.history['loss'],label = 'CNN+ features loss ')
plt.plot(history3.history['val_loss'],label = 'CNN+ features val_loss ')

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train2, X_test2, y_train2, y_test2 = train_test_split(images, classes_bi, test_size=0.3, random_state=69)

# %%
xtrain2 = np.expand_dims(X_train2, axis=-1)
xtest2 = np.expand_dims(X_test2, axis=-1)

# %%
#
X_train, X_test, y_train, y_test = train_test_split(imgs, classes_bi, test_size=0.3, random_state=69)

# %%
xtrain = np.expand_dims(X_train, axis=-1)
xtest = np.expand_dims(X_test, axis=-1)

# %%
from tensorflow.keras.layers import concatenate, Input ,Flatten,Dense,Dropout
from tensorflow.keras.models import Model
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D

# %%
X_train2[0].shape
# Out:
# (256, 256)

# %%
X_train[0].shape
# Out:
# (48, 26)

# %%
input_images = Input(shape=(X_train2[0].shape[0], X_train2[0].shape[1],1,))
x = Conv2D(kernel_size=(10,10), filters=32, activation='selu')(input_images)
x = MaxPool2D(5,5)(x)
x = Conv2D(filters=30,kernel_size = (3,3),activation='selu')(x)
x = MaxPool2D(2,2)(x)
x = Conv2D(filters=30,kernel_size = (3,3),activation='relu')(x)
x = MaxPool2D(2,2)(x)
x = Conv2D(filters=30,kernel_size = (3,3),activation='tanh')(x)
x = Flatten()(x)
x = Dense(15,activation='relu')(x)
x = Model(inputs=input_images, outputs=x)

#second model #two options (images or not)
input_features = Input(shape=(X_train[0].shape[0], X_train[0].shape[1],1,))
y = Conv2D(kernel_size=(5,5), filters=16, activation='selu')(input_features)
y = MaxPool2D(2,2)(y)
y = Conv2D(filters=10,kernel_size = (2,2),activation='selu')(y)
y = Flatten()(y)
y = Dense(15,activation='relu')(y)
y = Model(inputs=input_features, outputs=y)






# combine the output of the two branches
combined = concatenate([x.output, y.output])
# apply a FC layer and then a regression prediction on the
# combined outputs
z = Dense(30,activation='selu')(combined)
z = Dropout(0.2)(z)
z = Dense(15,activation=tf.keras.layers.LeakyReLU(alpha=0.3))(z)
z= Dense(5,activation = 'softmax')(z)
# our model will accept the inputs of the two branches and
# then output a single value
model4 = Model(inputs=[x.input, y.input], outputs=z)

# %%
print(model4.summary())
# Out:
# Model: "model_29"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_60 (Conv2D)             (None, 247, 247, 32  3232        ['input_23[0][0]']
#                                 )
#
#  max_pooling2d_43 (MaxPooling2D  (None, 49, 49, 32)  0           ['conv2d_60[0][0]']
#  )
#
#  conv2d_61 (Conv2D)             (None, 47, 47, 30)   8670        ['max_pooling2d_43[0][0]']
#
#  max_pooling2d_44 (MaxPooling2D  (None, 23, 23, 30)  0           ['conv2d_61[0][0]']
#  )
#
#  input_24 (InputLayer)          [(None, 48, 26, 1)]  0           []
#
#  conv2d_62 (Conv2D)             (None, 21, 21, 30)   8130        ['max_pooling2d_44[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 44, 22, 16)   416         ['input_24[0][0]']
#
#  max_pooling2d_45 (MaxPooling2D  (None, 10, 10, 30)  0           ['conv2d_62[0][0]']
#  )
#
#  max_pooling2d_46 (MaxPooling2D  (None, 22, 11, 16)  0           ['conv2d_64[0][0]']
#  )
#
#  conv2d_63 (Conv2D)             (None, 8, 8, 30)     8130        ['max_pooling2d_45[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 21, 10, 10)   650         ['max_pooling2d_46[0][0]']
#
#  flatten_19 (Flatten)           (None, 1920)         0           ['conv2d_63[0][0]']
#
#  flatten_20 (Flatten)           (None, 2100)         0           ['conv2d_65[0][0]']
#
#  dense_33 (Dense)               (None, 15)           28815       ['flatten_19[0][0]']
#
#  dense_34 (Dense)               (None, 15)           31515       ['flatten_20[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 30)           0           ['dense_33[0][0]',
#                                                                   'dense_34[0][0]']
#
#  dense_35 (Dense)               (None, 30)           930         ['concatenate_9[0][0]']
#
#  dropout_10 (Dropout)           (None, 30)           0           ['dense_35[0][0]']
#
#  dense_36 (Dense)               (None, 15)           465         ['dropout_10[0][0]']
#
#  dense_37 (Dense)               (None, 5)            80          ['dense_36[0][0]']
#
# ==================================================================================================
# Total params: 91,033
# Trainable params: 91,033
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from keras.utils.vis_utils import plot_model
plot_model(model4, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model4.compile(loss='categorical_crossentropy', metrics=['acc'],optimizer='adam')

# %%
history4=model4.fit( x=[xtrain2, xtrain], y=y_train, validation_data=([xtest2, xtest], y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 88/88 [==============================] - 102s 1s/step - loss: 1.5702 - acc: 0.2657 - val_loss: 1.3820 - val_acc: 0.3700
# Epoch 2/50
# 88/88 [==============================] - 101s 1s/step - loss: 1.2006 - acc: 0.4861 - val_loss: 1.1195 - val_acc: 0.5242
# Epoch 3/50
# 88/88 [==============================] - 101s 1s/step - loss: 1.0401 - acc: 0.5364 - val_loss: 1.0176 - val_acc: 0.5492
# Epoch 4/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.9547 - acc: 0.5850 - val_loss: 1.1038 - val_acc: 0.5608
# Epoch 5/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.9090 - acc: 0.6150 - val_loss: 0.9506 - val_acc: 0.6083
# Epoch 6/50
# 88/88 [==============================] - 100s 1s/step - loss: 0.8085 - acc: 0.6554 - val_loss: 0.8202 - val_acc: 0.6592
# Epoch 7/50
# 88/88 [==============================] - 100s 1s/step - loss: 0.7317 - acc: 0.6807 - val_loss: 0.8337 - val_acc: 0.6483
# Epoch 8/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.7041 - acc: 0.7029 - val_loss: 0.8367 - val_acc: 0.6875
# Epoch 9/50
# 88/88 [==============================] - 97s 1s/step - loss: 0.6508 - acc: 0.7268 - val_loss: 0.6898 - val_acc: 0.7392
# Epoch 10/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.6027 - acc: 0.7446 - val_loss: 0.7474 - val_acc: 0.7067
# Epoch 11/50
# 88/88 [==============================] - 96s 1s/step - loss: 0.6190 - acc: 0.7475 - val_loss: 0.7430 - val_acc: 0.7217
# Epoch 12/50
# 88/88 [==============================] - 98s 1s/step - loss: 0.5765 - acc: 0.7632 - val_loss: 0.6801 - val_acc: 0.7308
# Epoch 13/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.4962 - acc: 0.8018 - val_loss: 0.6397 - val_acc: 0.7558
# Epoch 14/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.4339 - acc: 0.8211 - val_loss: 0.6854 - val_acc: 0.7450
# Epoch 15/50
# 88/88 [==============================] - 103s 1s/step - loss: 0.4210 - acc: 0.8375 - val_loss: 0.7022 - val_acc: 0.7358
# Epoch 16/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.3787 - acc: 0.8536 - val_loss: 0.7471 - val_acc: 0.7300
# Epoch 17/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.3315 - acc: 0.8671 - val_loss: 0.7467 - val_acc: 0.7508
# Epoch 18/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.2907 - acc: 0.8868 - val_loss: 0.7865 - val_acc: 0.7550
# Epoch 19/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.2994 - acc: 0.8896 - val_loss: 0.8406 - val_acc: 0.7425
# Epoch 20/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.2467 - acc: 0.9050 - val_loss: 0.8272 - val_acc: 0.7383
# Epoch 21/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.2497 - acc: 0.9118 - val_loss: 0.9093 - val_acc: 0.7242
# Epoch 22/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.2582 - acc: 0.9125 - val_loss: 0.8884 - val_acc: 0.7258
# Epoch 23/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.1807 - acc: 0.9318 - val_loss: 0.9079 - val_acc: 0.7350
# Epoch 24/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.1779 - acc: 0.9346 - val_loss: 0.9234 - val_acc: 0.7458
# Epoch 25/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.1632 - acc: 0.9371 - val_loss: 1.1738 - val_acc: 0.7142
# Epoch 26/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.1919 - acc: 0.9311 - val_loss: 0.9566 - val_acc: 0.7183
# Epoch 27/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.1287 - acc: 0.9546 - val_loss: 1.0010 - val_acc: 0.7408
# Epoch 28/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.1289 - acc: 0.9532 - val_loss: 1.0543 - val_acc: 0.7350
# Epoch 29/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.0886 - acc: 0.9664 - val_loss: 1.0100 - val_acc: 0.7492
# Epoch 30/50
# 88/88 [==============================] - 102s 1s/step - loss: 0.0774 - acc: 0.9746 - val_loss: 1.1670 - val_acc: 0.7400
# Epoch 31/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.0532 - acc: 0.9821 - val_loss: 1.1108 - val_acc: 0.7417
# Epoch 32/50
# 88/88 [==============================] - 101s 1s/step - loss: 0.0658 - acc: 0.9793 - val_loss: 1.2800 - val_acc: 0.7308
# Epoch 33/50
# 88/88 [==============================] - 96s 1s/step - loss: 0.0862 - acc: 0.9679 - val_loss: 1.2830 - val_acc: 0.7283
# Epoch 34/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0874 - acc: 0.9661 - val_loss: 1.2907 - val_acc: 0.7567
# Epoch 35/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.1126 - acc: 0.9611 - val_loss: 1.3230 - val_acc: 0.7417
# Epoch 36/50
# 88/88 [==============================] - 96s 1s/step - loss: 0.0710 - acc: 0.9757 - val_loss: 1.2605 - val_acc: 0.7492
# Epoch 37/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0826 - acc: 0.9664 - val_loss: 1.3588 - val_acc: 0.7250
# Epoch 38/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.1065 - acc: 0.9604 - val_loss: 1.4907 - val_acc: 0.7133
# Epoch 39/50
# 88/88 [==============================] - 94s 1s/step - loss: 0.1184 - acc: 0.9564 - val_loss: 1.3895 - val_acc: 0.7417
# Epoch 40/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.1517 - acc: 0.9514 - val_loss: 1.2364 - val_acc: 0.7258
# Epoch 41/50
# 88/88 [==============================] - 94s 1s/step - loss: 0.0838 - acc: 0.9704 - val_loss: 1.2967 - val_acc: 0.7417
# Epoch 42/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0535 - acc: 0.9814 - val_loss: 1.3933 - val_acc: 0.7275
# Epoch 43/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0364 - acc: 0.9893 - val_loss: 1.4386 - val_acc: 0.7275
# Epoch 44/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0318 - acc: 0.9893 - val_loss: 1.3920 - val_acc: 0.7375
# Epoch 45/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0199 - acc: 0.9939 - val_loss: 1.3990 - val_acc: 0.7475
# Epoch 46/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0187 - acc: 0.9950 - val_loss: 1.4723 - val_acc: 0.7392
# Epoch 47/50
# 88/88 [==============================] - 94s 1s/step - loss: 0.0085 - acc: 0.9979 - val_loss: 1.4716 - val_acc: 0.7408
# Epoch 48/50
# 88/88 [==============================] - 94s 1s/step - loss: 0.0074 - acc: 0.9986 - val_loss: 1.5398 - val_acc: 0.7467
# Epoch 49/50
# 88/88 [==============================] - 94s 1s/step - loss: 0.0048 - acc: 0.9993 - val_loss: 1.4939 - val_acc: 0.7350
# Epoch 50/50
# 88/88 [==============================] - 95s 1s/step - loss: 0.0050 - acc: 0.9993 - val_loss: 1.6057 - val_acc: 0.7375

# %%
sns.boxplot(data=[history2.history['val_acc'],history3.history['val_acc'],history4.history['val_acc']],showfliers=False)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=[history2.history['val_acc'][10:],history3.history['val_acc'][10:],history4.history['val_acc'][10:]],showfliers=False)
# Out:
# <AxesSubplot:>

# %%
plt.plot(history2.history['val_acc'],label = 'CNN validation accuracy ')
plt.plot(history3.history['val_acc'],label = 'CNN + features validation accuracy ')
plt.plot(history4.history['val_acc'],label = 'CNN² + features validation accuracy ')
plt.ylim(0.67,0.79)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history2.history['acc'],label = 'CNN accuracy ')
plt.plot(history2.history['val_acc'],label = 'CNN validation accuracy ')
plt.plot(history3.history['acc'],label = 'CNN + features accuracy ')
plt.plot(history3.history['val_acc'],label = 'CNN + features validation accuracy ')
plt.plot(history4.history['acc'],label = 'CNN² + features accuracy ')
plt.plot(history4.history['val_acc'],label = 'CNN² + features validation accuracy ')
                    
                    
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()
# summarize history for loss
plt.plot(history2.history['loss'],label = 'CNN loss ')
plt.plot(history2.history['val_loss'],label = 'CNN val_loss ')
plt.plot(history3.history['loss'],label = 'CNN+ features loss ')
plt.plot(history3.history['val_loss'],label = 'CNN+ features val_loss ')
plt.plot(history4.history['loss'],label = 'CNN+ features loss ')
plt.plot(history4.history['val_loss'],label = 'CNN+ features val_loss ')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #### Classification directe des images de persistance

# %%
from ripser import Rips
from persim import PersImage
from persim import PersistenceImager

# %%
rips = Rips(maxdim=1, coeff=2)
diagrams = [rips.fit_transform(img) for img in images]
diagrams_h1 = [rips.fit_transform(img)[1] for img in images]
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    rips.plot(diagrams[i], show=False)
    plt.title(classes[i])
    #plt.axis("off")

# %%
pimgr = PersistenceImager(pixel_size=0.25)
pimgr.fit(diagrams_h1)
imgs = pimgr.transform(diagrams_h1)

# %%
plt.figure(figsize=(10, 10))

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(imgs[i])
    plt.title(classes[i])
    plt.axis("off")

# %% [markdown]
# Again, for the five-class classification, we tried different models like XGBoost and SVM ... but they did not give interesting results and it is not useful to mention them here.

# %%
imgs_array = np.array([img.flatten() for img in imgs])

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs_array_5c, gender_classes_bi.flatten(), test_size=0.40, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs_array_5c, np.argmax(classes_bi, axis=1), test_size=0.40, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs_array_5c, np.argmax(classes_bi, axis=1), test_size=0.40, random_state=42)
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# LogisticRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.31125

# %%
X_train, X_test, y_train, y_test = train_test_split([img.flatten() for img in images], np.argmax(classes_bi, axis=1), test_size=0.33, random_state=42)

from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score


model = XGBClassifier() 
model.fit(X_train, y_train)
y_pred = model.predict(X_test) 
predictions = [value for value in y_pred]
accuracy = accuracy_score(y_test, predictions) 
print("Accuracy: %.2f%%" % (accuracy * 100.0))

import lightgbm as lgb
clf = lgb.LGBMClassifier()
clf.fit(X_train, y_train)

y_pred=clf.predict(X_test)
accuracy = accuracy_score(y_test, predictions) 
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# [11:16:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 33.03%
# Accuracy: 33.03%

# %% [markdown]
# It is not useful for direct classification

# %% [markdown]
# ## The PersLay model

# %% [markdown]
# ### Rips and Alpha diagrams

# %%
from ripser import Rips
from persim import PersImage
from persim import PersistenceImager

# %%
t=1.0
for i in range(8):
    try :
        img = np.random.choice(list(range(len(images_over))))
        img=images[img]*100
        img[img < t] = 0
        rips_complex = gudhi.RipsComplex(points=np.dstack((np.nonzero(img)[0],np.nonzero(img)[1]))[0],
                                    max_edge_length=5) #Pour ne prendre que les points non nuls

        simplex_tree = rips_complex.create_simplex_tree(max_dimension=3)
        diag = simplex_tree.persistence(persistence_dim_max=True)
        print(gender_classes_bi_over[img])
        gudhi.plot_persistence_diagram(diag)
        gudhi.plot_persistence_barcode(diag)
        plt.show()
    except:
        continue
# Out:
# Error: Canceled future for execute_request message before replies were done
# at t.KernelShellFutureHandler.dispose (c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1204175)
# at c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1223227
# at Map.forEach (<anonymous>)
# at v._clearKernelState (c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1223212)
# at v.dispose (c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:1216694)
# at c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:533674
# at t.swallowExceptions (c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:913059)
# at dispose (c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:533652)
# at t.RawSession.dispose (c:\Users\anass\.vscode\extensions\ms-toolsai.jupyter-2022.3.1000901801\out\extension.js:2:537330)
# at processTicksAndRejections (node:internal/process/task_queues:96:5)

# %%
t=1.0
for i in range(8):
    try :
        img = np.random.choice(list(range(len(images_over))))
        print(gender_classes_bi_over[img])
        img=images[img]*100
        img[img < t] = 0
        alpha_complex = gudhi.AlphaComplex(points=np.dstack((np.nonzero(img)[0],np.nonzero(img)[1]))[0],precision = 'fast')
        #Pour ne prendre que les points non nuls
        simplex_tree = alpha_complex.create_simplex_tree()
        diag = simplex_tree.persistence()
        gudhi.plot_persistence_diagram(diag)
        gudhi.plot_persistence_barcode(diag)
        plt.show()
    except:
        continue
# Out:
# 1
# 0
# 0
# 1
# 1
# 1
# 1
# 1

# %% [markdown]
# We tried to see some rips and alpha diagrams by gudhi, and as it takes a lot of time for the rips diagrams we will use gudhi alpha diagrams and ripser rips diagrams (in the end the diagrams will be tables recognizable by the perslay model).

# %% [markdown]
# ### Reproduction of the tutorial of the PerslaLay layer (by Mathieu Carrière and Théo Lacombe)

# %% [markdown]
# A model for PersLay: a neural network layer for persistence diagrams and other topological signatures (like Betticurves..)

# %% [markdown]
# - We have already tried the tutorial done by Carrière and Lacombe using one of their datasets, now we will apply it to the fingerprint dataset.
# - Next, we generate the persistence diagrams
# - Then, we create a model using PersLay channels as the first layers to handle the persistence diagrams.
# - Finally, we train the resulting neural network.

# %% [markdown]
# #### Import the required Python packages

# %% [markdown]
# Import Numpy, Scikit-learn, TensorFlow, PersLay.

# %%
import numpy as np
import tensorflow as tf
from sklearn.ensemble import *
from sklearn.svm import *
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV, KFold, ShuffleSplit
from tensorflow import random_uniform_initializer as rui
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from perslay import PerslayModel

# %% [markdown]
# ### Creation of persistence diagrams

# %% [markdown]
# - Persistence diagrams must be given in the following format:
# Suppose you have $N$ observations. For each of them, we construct $K$ different persistence diagrams (e.g., persistence diagrams in different homology dimensions, and/or for different filtering, etc.).
#
# - Then, we must provide a `diags_dict` variable which is a `dictionary`, whose $K$ keys are the names of the types of persistence diagrams (e.g., `"Rips_dim_0"`, `"Cech_dim_1"`)- For each $k_i$ key, $1 \leq i \leq K$, the corresponding value is a `list` of `np.arrays`, each array corresponds to a persistence diagram.
#
# - Moreover, each list must have the same length $N$ (you must have the same number of persistence diagrams generated for each list).And you must respect the order (i.e. the first element of each list must correspond to the persistence diagram generated with the first observation, and so on).
#
# - Here is an example:
#
# `diags_tmp = {"Alpha0":[np.array([[0.1, 0.2], [0.2, 0.5], [0.3, 0.9]]), np.array([[0.1, 0.4], [0.3, 0.5]]),], "Alpha1":[np.array([[0.1, 0.4], [0.2, 0.6], [0.4, 0.9]]), np.array([[0.1, 0.2], [0.5, 0.7], [0.8, 0.9]])]}`

# %% [markdown]
# # RipsComplex and AlphaComplex and storage

# %% [markdown]
# __Important note__ : you do not need to recreate the diagrams, you can load them directly.

# %%
from progressbar import ProgressBar
pbar = ProgressBar()

# %%
def diag_func(diag):
    one_arrays = []
    zero_arrays = []
    for x in diag:
        if x[0]==1 :
            one_arrays.append(list(x[1]))
        if x[0]==0 :
            zero_arrays.append(list(x[1]))
    one_arrays = np.array(one_arrays)
    zero_arrays = np.array(zero_arrays)
    return one_arrays,zero_arrays

# %%
Alpha_dim_0_diags = []
Alpha_dim_1_diags = [] 
Rips_dim_0_diags = [] 
Rips_dim_1_diags = []
for img in pbar(images_over):
    rips = Rips(maxdim=1, coeff=2, verbose=False)
    diag = rips.fit_transform(img)
    diagrams_h0 = diag[0]
    diagrams_h1 = diag[1]
    cloud2D = np.dstack((np.nonzero(img)[0],np.nonzero(img)[1]))[0]
    alpha_complex = gudhi.AlphaComplex(points=cloud2D,precision = 'fast')
    simplex_tree = alpha_complex.create_simplex_tree()
    diag = simplex_tree.persistence()
    diagrams_h0_a,diagrams_h1_a = diag_func(diag)
    Alpha_dim_0_diags.append(diagrams_h0_a)
    Alpha_dim_1_diags.append(diagrams_h1_a)
    Rips_dim_0_diags.append(diagrams_h0)
    Rips_dim_1_diags.append(diagrams_h1)
# Out:
# 100% |########################################################################|

# %% [markdown]
# 147 minutes needed to generate the diagrams

# %% [markdown]
# ##### Storing the diagrams
# For storage, we tried pickle and np.load and h5py, the first two give files of about 6 gigabytes, so it is not practical.
# the last one has a format problem. The best solution is hickle (combination of pickle, and h5py which avoids format and memory problems
# )

# %%
import hickle as hkl
# Dump data, with compression
saved_data = (Alpha_dim_0_diags,Alpha_dim_1_diags,Rips_dim_0_diags,Rips_dim_1_diags)
hkl.dump(saved_data, 'saved_Alpha_diags_Rips_diags_for_images_over.hkl', mode='w', compression='gzip')

# %% [markdown]
# __Important__ : To load the diagrams :

# %%
import hickle as hkl
# Load data
Alpha_dim_0_diags,Alpha_dim_1_diags,Rips_dim_0_diags,Rips_dim_1_diags = hkl.load('saved_Alpha_diags_Rips_diags_for_images_over.hkl')

# %%
diags_dict = {"Alpha0":Alpha_dim_0_diags,"Alpha1":Alpha_dim_1_diags,"Rips_dim_0":Rips_dim_0_diags,"Rips_dim_1":Rips_dim_1_diags}

# %%
import sys
sys.getsizeof(diags_dict)
# Out:
# 232

# %% [markdown]
# Now you need to provide the labels for each persistence diagram.

# %%
L = gender_classes_bi_over

# %% [markdown]
# We can use some additional "standard" features in your network. These features should be provided as $N \times d$ `np.array`, where $N$ is the number of observations (as before) and $d$ is the feature dimension.
# We will not use additional features in this case, we will use an empty array of size $(N,0)$, where $N$ is the number of observations (This is a requirement of the Perslay layer).

# %%
N = len(images_over)
F = np.array([[]]*N)

# %% [markdown]
# ### Preprocessing persistence diagrams

# %%
import gudhi.representations as tda

thresh = 1000

# Whole pipeline
tmp = Pipeline([
        ("Selector",      tda.DiagramSelector(use=True, point_type="finite")),
        ("ProminentPts",  tda.ProminentPoints(use=True, num_pts=thresh)),
        ("Scaler",        tda.DiagramScaler(use=True, scalers=[([0,1], MinMaxScaler())])),
        ("Padding",       tda.Padding(use=True)),
                ])

prm = {filt: {"ProminentPts__num_pts": min(thresh, max([len(dgm) for dgm in diags_dict[filt]]))} 
       for filt in diags_dict.keys() if max([len(dgm) for dgm in diags_dict[filt]]) > 0}

# Apply the previous pipeline on the different filtrations.
diags = []
for dt in prm.keys():
    param = prm[dt]
    tmp.set_params(**param)
    diags.append(tmp.fit_transform(diags_dict[dt]))

# For each filtration, concatenate all diagrams in a single array.
D, npts = [], len(diags[0])
for dt in range(len(prm.keys())):
    D.append(np.array(np.concatenate([diags[dt][i][np.newaxis,:] for i in range(npts)],axis=0),dtype=np.float32))

# %% [markdown]
# ### Using PersLay in a neural network

# %% [markdown]
# ### Definition of the network

# %% [markdown]
# Initialization of the list of PersLay parameters. This list will contain the different parameters of the PersLay channels (there is one channel per type of filtration/diagram).

# %%
perslay_parameters = []

# %%
perslay_channel = {}

# %%
perslay_channel["pweight_train"] = True
perslay_channel["layer_train"]   = True
perslay_channel["final_model"]   = "identity"

# %% [markdown]
# ##### Layer type

# %% [markdown]
# Choice of layer type, must be one of :
# - `"Image"` for a persistence image layer.
# - `"PermutationEquivariant"` for a permutation equivariant layer (as in [2]).
# - `"Exponential"` for an exponential structure element layer (as in [3]).
# - `"Rational"` for a rational structure element layer (as in [3]).
# - `"RationalHat"` for a rational hat structure element layer (as in [3]).
# - `"Landscape"` for a persistence landscape layer.
# - `"BettiCurve"` for a Betti curve layer.
# - `"Entropy"` for a persistence entropy layer.

# %%
perslay_channel["layer"]           = "Landscape"
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0)

# %%
perslay_channel["layer"]           = "Image"
perslay_channel["image_size"]      = (20, 20)
perslay_channel["image_bnds"]      = ((-.001, 1.001), (-.001, 1.001))
perslay_channel["lvariance_init"]  = 3.

# %%
perslay_channel["layer"]           = "PermutationEquivariant"
perslay_channel["lpeq"]            = [(5, "max")]
perslay_channel["lweight_init"]    = rui(0.0, 1.0)
perslay_channel["lbias_init"]      = rui(0.0, 1.0)
perslay_channel["lgamma_init"]     = rui(0.0, 1.0)

# %%
perslay_channel["layer"]           = "Exponential"
perslay_channel["lnum"]            = 25
perslay_channel["lmean_init"]      = rui(0.0, 1.0)
perslay_channel["lvariance_init"]  = rui(3.0, 3.0)

# %%
perslay_channel["layer"]           = "Rational"
perslay_channel["lnum"]            = 25
perslay_channel["lmean_init"]      = rui(0.0, 1.0)
perslay_channel["lvariance_init"]  = rui(3.0, 3.0) 
perslay_channel["lalpha_init"]     = rui(3.0, 3.0)

# %%
perslay_channel["layer"]           = "RationalHat"
perslay_channel["lnum"]            = 25
perslay_channel["lmean_init"]      = rui(0.0, 1.0)
perslay_channel["lr_init"]         = rui(3.0, 3.0) 
perslay_channel["q"]               = 2

# %%
perslay_channel["layer"]           = "BettiCurve"
perslay_channel["theta"]           = 10
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0)

# %%
perslay_channel["layer"]           = "Entropy"
perslay_channel["theta"]           = 10
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0)

# %% [markdown]
# ##### Weight function

# %% [markdown]
# Choice of weight function, must be one of :
# - `"power"`, for the distance to the diagonal with some exponent.
# - `"grid"`, for a piecewise-constant function defined with pixel values.
# - `"gmix"`, for a weight function defined as a mixture of Gaussians.
# - `None`, for a constant weight function.

# %%
perslay_channel["pweight"]       = "power"
perslay_channel["pweight_init"]  = 1.
perslay_channel["pweight_power"] = 1

# %%
perslay_channel["pweight"]       = "grid"
perslay_channel["pweight_size"]  = [20,20]
perslay_channel["pweight_bnds"]  = ((-.001, 1.001), (-.001, 1.001))
perslay_channel["pweight_init"]  = rui(1.0, 1.0)

# %%
perslay_channel["pweight"]       = "gmix"
perslay_channel["pweight_num"]   = 3
perslay_channel["pweight_init"]  = np.array(np.vstack([np.random.uniform(0.,1.,[2,3]), 
                                                        5.*np.ones([2,3])]), dtype=np.float32)

# %%
perslay_channel["pweight"]       = None

# %% [markdown]
# ##### Permutation-invariant operation

# %% [markdown]
# Choice of the permutation invariant operator, must be one of :
#
# - `"sum"`.
# - `"topk"`, will select the $k$ highest values, specified in `keep`.
# - `"max"`.
# - `"mean"`.

# %%
perslay_channel["perm_op"] = "sum"

# %%
perslay_channel["perm_op"] = "topk"
perslay_channel["keep"]    = 5

# %%
perslay_channel["perm_op"] = "max"

# %%
perslay_channel["perm_op"] = "mean"

# %% [markdown]
# ##### Definition of the model and choice of the optimizer, the loss and the metric.

# %% [markdown]
# ######  Choice of parameters:
#
# We have tried many examples, and we will make a search grid later, but for now, as a first attempt, we use :
# layer : Landscape
# pweight : power
# perm_op : mean
#
#
# the results presented below correspond to this one

# %%
perslay_parameters = [perslay_channel for _ in range(len(D))]

# %%
import tensorflow_addons as tfa

# %% [markdown]
# ## Train the network

# %%
rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid")])
model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split
X_train0, X_test0, y_train, y_test = train_test_split(D[0], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train1, X_test1, y_train, y_test = train_test_split(D[1], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train2, X_test2, y_train, y_test = train_test_split(D[2], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train3, X_test3, y_train, y_test = train_test_split(D[3], gender_classes_bi_over, test_size=0.3, random_state=69)
feats_train, feats_test, y_train, y_test = train_test_split(F, gender_classes_bi_over, test_size=0.3, random_state=69)

# %%
diags_train = [X_train0,X_train1,X_train2,X_train3]
diags_test = [X_test0,X_test1,X_test2,X_test3]

# %%
history = model.fit(x=[diags_train, feats_train], y=y_train, validation_data=([diags_test, feats_test], y_test), epochs=100, batch_size=128, shuffle=True, verbose=1)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 16s 447ms/step - loss: 0.4799 - accuracy: 0.7833 - val_loss: 0.4959 - val_accuracy: 0.7723
# Epoch 2/100
# 36/36 [==============================] - 16s 449ms/step - loss: 0.4793 - accuracy: 0.7833 - val_loss: 0.4938 - val_accuracy: 0.7759
# Epoch 3/100
# 36/36 [==============================] - 16s 447ms/step - loss: 0.4797 - accuracy: 0.7813 - val_loss: 0.4946 - val_accuracy: 0.7713
# Epoch 4/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4744 - accuracy: 0.7855 - val_loss: 0.5138 - val_accuracy: 0.7636
# Epoch 5/100
# 36/36 [==============================] - 16s 442ms/step - loss: 0.4752 - accuracy: 0.7884 - val_loss: 0.4902 - val_accuracy: 0.7856
# Epoch 6/100
# 36/36 [==============================] - 16s 442ms/step - loss: 0.4781 - accuracy: 0.7793 - val_loss: 0.4919 - val_accuracy: 0.7774
# Epoch 7/100
# 36/36 [==============================] - 16s 449ms/step - loss: 0.4734 - accuracy: 0.7855 - val_loss: 0.4890 - val_accuracy: 0.7815
# Epoch 8/100
# 36/36 [==============================] - 16s 446ms/step - loss: 0.4742 - accuracy: 0.7824 - val_loss: 0.5204 - val_accuracy: 0.7472
# Epoch 9/100
# 36/36 [==============================] - 16s 443ms/step - loss: 0.4755 - accuracy: 0.7866 - val_loss: 0.4893 - val_accuracy: 0.7815
# Epoch 10/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4721 - accuracy: 0.7820 - val_loss: 0.4919 - val_accuracy: 0.7841
# Epoch 11/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4696 - accuracy: 0.7901 - val_loss: 0.4880 - val_accuracy: 0.7779
# Epoch 12/100
# 36/36 [==============================] - 17s 463ms/step - loss: 0.4708 - accuracy: 0.7857 - val_loss: 0.4879 - val_accuracy: 0.7831
# Epoch 13/100
# 36/36 [==============================] - 16s 441ms/step - loss: 0.4705 - accuracy: 0.7824 - val_loss: 0.4870 - val_accuracy: 0.7790
# Epoch 14/100
# 36/36 [==============================] - 16s 440ms/step - loss: 0.4697 - accuracy: 0.7848 - val_loss: 0.4883 - val_accuracy: 0.7856
# Epoch 15/100
# 36/36 [==============================] - 17s 472ms/step - loss: 0.4703 - accuracy: 0.7925 - val_loss: 0.4954 - val_accuracy: 0.7692
# Epoch 16/100
# 36/36 [==============================] - 16s 460ms/step - loss: 0.4732 - accuracy: 0.7862 - val_loss: 0.4866 - val_accuracy: 0.7779
# Epoch 17/100
# 36/36 [==============================] - 16s 456ms/step - loss: 0.4708 - accuracy: 0.7884 - val_loss: 0.4908 - val_accuracy: 0.7764
# Epoch 18/100
# 36/36 [==============================] - 16s 451ms/step - loss: 0.4698 - accuracy: 0.7886 - val_loss: 0.4849 - val_accuracy: 0.7836
# Epoch 19/100
# 36/36 [==============================] - 16s 445ms/step - loss: 0.4683 - accuracy: 0.7835 - val_loss: 0.4912 - val_accuracy: 0.7831
# Epoch 20/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4704 - accuracy: 0.7868 - val_loss: 0.4883 - val_accuracy: 0.7754
# Epoch 21/100
# 36/36 [==============================] - 16s 447ms/step - loss: 0.4677 - accuracy: 0.7868 - val_loss: 0.4863 - val_accuracy: 0.7774
# Epoch 22/100
# 36/36 [==============================] - 16s 445ms/step - loss: 0.4680 - accuracy: 0.7899 - val_loss: 0.4845 - val_accuracy: 0.7836
# Epoch 23/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4669 - accuracy: 0.7927 - val_loss: 0.4829 - val_accuracy: 0.7862
# Epoch 24/100
# 36/36 [==============================] - 16s 451ms/step - loss: 0.4656 - accuracy: 0.7925 - val_loss: 0.4854 - val_accuracy: 0.7821
# Epoch 25/100
# 36/36 [==============================] - 16s 459ms/step - loss: 0.4649 - accuracy: 0.7886 - val_loss: 0.4884 - val_accuracy: 0.7697
# Epoch 26/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4646 - accuracy: 0.7901 - val_loss: 0.4847 - val_accuracy: 0.7851
# Epoch 27/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4666 - accuracy: 0.7910 - val_loss: 0.4842 - val_accuracy: 0.7821
# Epoch 28/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4645 - accuracy: 0.7901 - val_loss: 0.4824 - val_accuracy: 0.7851
# Epoch 29/100
# 36/36 [==============================] - 16s 448ms/step - loss: 0.4647 - accuracy: 0.7923 - val_loss: 0.4959 - val_accuracy: 0.7815
# Epoch 30/100
# 36/36 [==============================] - 16s 449ms/step - loss: 0.4666 - accuracy: 0.7905 - val_loss: 0.4853 - val_accuracy: 0.7821
# Epoch 31/100
# 36/36 [==============================] - 17s 470ms/step - loss: 0.4632 - accuracy: 0.7938 - val_loss: 0.4876 - val_accuracy: 0.7708
# Epoch 32/100
# 36/36 [==============================] - 16s 456ms/step - loss: 0.4648 - accuracy: 0.7930 - val_loss: 0.4825 - val_accuracy: 0.7831
# Epoch 33/100
# 36/36 [==============================] - 16s 461ms/step - loss: 0.4628 - accuracy: 0.7934 - val_loss: 0.4862 - val_accuracy: 0.7790
# Epoch 34/100
# 36/36 [==============================] - 16s 454ms/step - loss: 0.4661 - accuracy: 0.7936 - val_loss: 0.4916 - val_accuracy: 0.7800
# Epoch 35/100
# 36/36 [==============================] - 16s 440ms/step - loss: 0.4623 - accuracy: 0.7947 - val_loss: 0.4854 - val_accuracy: 0.7826
# Epoch 36/100
# 36/36 [==============================] - 16s 432ms/step - loss: 0.4631 - accuracy: 0.7916 - val_loss: 0.4872 - val_accuracy: 0.7800
# Epoch 37/100
# 36/36 [==============================] - 17s 482ms/step - loss: 0.4617 - accuracy: 0.7952 - val_loss: 0.4824 - val_accuracy: 0.7856
# Epoch 38/100
# 36/36 [==============================] - 19s 518ms/step - loss: 0.4649 - accuracy: 0.7912 - val_loss: 0.4931 - val_accuracy: 0.7723
# Epoch 39/100
# 36/36 [==============================] - 17s 475ms/step - loss: 0.4641 - accuracy: 0.7914 - val_loss: 0.4841 - val_accuracy: 0.7851
# Epoch 40/100
# 36/36 [==============================] - 17s 466ms/step - loss: 0.4634 - accuracy: 0.7919 - val_loss: 0.4819 - val_accuracy: 0.7831
# Epoch 41/100
# 36/36 [==============================] - 17s 473ms/step - loss: 0.4624 - accuracy: 0.7923 - val_loss: 0.4864 - val_accuracy: 0.7826
# Epoch 42/100
# 36/36 [==============================] - 16s 456ms/step - loss: 0.4614 - accuracy: 0.7947 - val_loss: 0.4838 - val_accuracy: 0.7723
# Epoch 43/100
# 36/36 [==============================] - 18s 498ms/step - loss: 0.4620 - accuracy: 0.7938 - val_loss: 0.4809 - val_accuracy: 0.7826
# Epoch 44/100
# 36/36 [==============================] - 16s 458ms/step - loss: 0.4615 - accuracy: 0.7919 - val_loss: 0.4812 - val_accuracy: 0.7785
# Epoch 45/100
# 36/36 [==============================] - 16s 460ms/step - loss: 0.4620 - accuracy: 0.7934 - val_loss: 0.4918 - val_accuracy: 0.7826
# Epoch 46/100
# 36/36 [==============================] - 18s 498ms/step - loss: 0.4609 - accuracy: 0.7938 - val_loss: 0.4858 - val_accuracy: 0.7774
# Epoch 47/100
# 36/36 [==============================] - 17s 467ms/step - loss: 0.4597 - accuracy: 0.7952 - val_loss: 0.4839 - val_accuracy: 0.7851
# Epoch 48/100
# 36/36 [==============================] - 18s 493ms/step - loss: 0.4615 - accuracy: 0.7927 - val_loss: 0.4892 - val_accuracy: 0.7733
# Epoch 49/100
# 36/36 [==============================] - 17s 474ms/step - loss: 0.4667 - accuracy: 0.7960 - val_loss: 0.4818 - val_accuracy: 0.7826
# Epoch 50/100
# 36/36 [==============================] - 17s 479ms/step - loss: 0.4621 - accuracy: 0.7941 - val_loss: 0.4847 - val_accuracy: 0.7831
# Epoch 51/100
# 36/36 [==============================] - 16s 455ms/step - loss: 0.4601 - accuracy: 0.7952 - val_loss: 0.4817 - val_accuracy: 0.7810
# Epoch 52/100
# 36/36 [==============================] - 16s 454ms/step - loss: 0.4574 - accuracy: 0.7965 - val_loss: 0.4793 - val_accuracy: 0.7785
# Epoch 53/100
# 36/36 [==============================] - 18s 494ms/step - loss: 0.4636 - accuracy: 0.7903 - val_loss: 0.4832 - val_accuracy: 0.7810
# Epoch 54/100
# 36/36 [==============================] - 17s 483ms/step - loss: 0.4641 - accuracy: 0.7952 - val_loss: 0.4795 - val_accuracy: 0.7785
# Epoch 55/100
# 36/36 [==============================] - 18s 498ms/step - loss: 0.4593 - accuracy: 0.7960 - val_loss: 0.4814 - val_accuracy: 0.7795
# Epoch 56/100
# 36/36 [==============================] - 18s 496ms/step - loss: 0.4604 - accuracy: 0.7974 - val_loss: 0.4827 - val_accuracy: 0.7785
# Epoch 57/100
# 36/36 [==============================] - 17s 480ms/step - loss: 0.4611 - accuracy: 0.7943 - val_loss: 0.4800 - val_accuracy: 0.7831
# Epoch 58/100
# 36/36 [==============================] - 16s 452ms/step - loss: 0.4599 - accuracy: 0.7989 - val_loss: 0.4811 - val_accuracy: 0.7841
# Epoch 59/100
# 36/36 [==============================] - 17s 469ms/step - loss: 0.4596 - accuracy: 0.7956 - val_loss: 0.4798 - val_accuracy: 0.7831
# Epoch 60/100
# 36/36 [==============================] - 16s 452ms/step - loss: 0.4596 - accuracy: 0.7969 - val_loss: 0.4838 - val_accuracy: 0.7759
# Epoch 61/100
# 36/36 [==============================] - 17s 461ms/step - loss: 0.4596 - accuracy: 0.7949 - val_loss: 0.4857 - val_accuracy: 0.7723
# Epoch 62/100
# 36/36 [==============================] - 17s 477ms/step - loss: 0.4596 - accuracy: 0.7971 - val_loss: 0.4824 - val_accuracy: 0.7785
# Epoch 63/100
# 36/36 [==============================] - 19s 542ms/step - loss: 0.4577 - accuracy: 0.7998 - val_loss: 0.4791 - val_accuracy: 0.7815
# Epoch 64/100
# 36/36 [==============================] - 18s 493ms/step - loss: 0.4597 - accuracy: 0.7949 - val_loss: 0.4785 - val_accuracy: 0.7831
# Epoch 65/100
# 36/36 [==============================] - 17s 474ms/step - loss: 0.4584 - accuracy: 0.7967 - val_loss: 0.4867 - val_accuracy: 0.7856
# Epoch 66/100
# 36/36 [==============================] - 16s 458ms/step - loss: 0.4560 - accuracy: 0.7998 - val_loss: 0.4810 - val_accuracy: 0.7815
# Epoch 67/100
# 36/36 [==============================] - 16s 454ms/step - loss: 0.4573 - accuracy: 0.7958 - val_loss: 0.4781 - val_accuracy: 0.7826
# Epoch 68/100
# 36/36 [==============================] - 16s 454ms/step - loss: 0.4577 - accuracy: 0.7960 - val_loss: 0.4876 - val_accuracy: 0.7867
# Epoch 69/100
# 36/36 [==============================] - 16s 455ms/step - loss: 0.4581 - accuracy: 0.7949 - val_loss: 0.4782 - val_accuracy: 0.7800
# Epoch 70/100
# 36/36 [==============================] - 16s 451ms/step - loss: 0.4581 - accuracy: 0.7963 - val_loss: 0.4879 - val_accuracy: 0.7713
# Epoch 71/100
# 36/36 [==============================] - 16s 457ms/step - loss: 0.4587 - accuracy: 0.7947 - val_loss: 0.4785 - val_accuracy: 0.7800
# Epoch 72/100
# 36/36 [==============================] - 17s 482ms/step - loss: 0.4555 - accuracy: 0.7949 - val_loss: 0.4771 - val_accuracy: 0.7872
# Epoch 73/100
# 36/36 [==============================] - 18s 516ms/step - loss: 0.4567 - accuracy: 0.7974 - val_loss: 0.4774 - val_accuracy: 0.7815
# Epoch 74/100
# 36/36 [==============================] - 20s 548ms/step - loss: 0.4586 - accuracy: 0.7991 - val_loss: 0.4765 - val_accuracy: 0.7836
# Epoch 75/100
# 36/36 [==============================] - 19s 515ms/step - loss: 0.4595 - accuracy: 0.7991 - val_loss: 0.4782 - val_accuracy: 0.7821
# Epoch 76/100
# 36/36 [==============================] - 17s 475ms/step - loss: 0.4581 - accuracy: 0.7971 - val_loss: 0.4763 - val_accuracy: 0.7826
# Epoch 77/100
# 36/36 [==============================] - 18s 503ms/step - loss: 0.4558 - accuracy: 0.7947 - val_loss: 0.4810 - val_accuracy: 0.7867
# Epoch 78/100
# 36/36 [==============================] - 17s 479ms/step - loss: 0.4546 - accuracy: 0.7993 - val_loss: 0.4750 - val_accuracy: 0.7862
# Epoch 79/100
# 36/36 [==============================] - 17s 480ms/step - loss: 0.4557 - accuracy: 0.7960 - val_loss: 0.4850 - val_accuracy: 0.7795
# Epoch 80/100
# 36/36 [==============================] - 18s 495ms/step - loss: 0.4589 - accuracy: 0.7943 - val_loss: 0.4780 - val_accuracy: 0.7831
# Epoch 81/100
# 36/36 [==============================] - 18s 491ms/step - loss: 0.4573 - accuracy: 0.7980 - val_loss: 0.4776 - val_accuracy: 0.7785
# Epoch 82/100
# 36/36 [==============================] - 17s 479ms/step - loss: 0.4544 - accuracy: 0.7985 - val_loss: 0.4801 - val_accuracy: 0.7862
# Epoch 83/100
# 36/36 [==============================] - 17s 486ms/step - loss: 0.4546 - accuracy: 0.7987 - val_loss: 0.4825 - val_accuracy: 0.7851
# Epoch 84/100
# 36/36 [==============================] - 17s 474ms/step - loss: 0.4560 - accuracy: 0.7963 - val_loss: 0.4770 - val_accuracy: 0.7851
# Epoch 85/100
# 36/36 [==============================] - 17s 481ms/step - loss: 0.4555 - accuracy: 0.7982 - val_loss: 0.4837 - val_accuracy: 0.7764
# Epoch 86/100
# 36/36 [==============================] - 18s 490ms/step - loss: 0.4553 - accuracy: 0.7985 - val_loss: 0.4784 - val_accuracy: 0.7877
# Epoch 87/100
# 36/36 [==============================] - 19s 541ms/step - loss: 0.4549 - accuracy: 0.7991 - val_loss: 0.4804 - val_accuracy: 0.7877
# Epoch 88/100
# 36/36 [==============================] - 18s 491ms/step - loss: 0.4570 - accuracy: 0.7976 - val_loss: 0.4797 - val_accuracy: 0.7856
# Epoch 89/100
# 36/36 [==============================] - 16s 454ms/step - loss: 0.4540 - accuracy: 0.7949 - val_loss: 0.4781 - val_accuracy: 0.7877
# Epoch 90/100
# 36/36 [==============================] - 17s 463ms/step - loss: 0.4544 - accuracy: 0.7938 - val_loss: 0.4816 - val_accuracy: 0.7836
# Epoch 91/100
# 36/36 [==============================] - 16s 455ms/step - loss: 0.4564 - accuracy: 0.7925 - val_loss: 0.4789 - val_accuracy: 0.7826
# Epoch 92/100
# 36/36 [==============================] - 17s 474ms/step - loss: 0.4563 - accuracy: 0.7989 - val_loss: 0.4777 - val_accuracy: 0.7892
# Epoch 93/100
# 36/36 [==============================] - 16s 446ms/step - loss: 0.4563 - accuracy: 0.7980 - val_loss: 0.4744 - val_accuracy: 0.7867
# Epoch 94/100
# 36/36 [==============================] - 16s 447ms/step - loss: 0.4545 - accuracy: 0.7956 - val_loss: 0.4813 - val_accuracy: 0.7764
# Epoch 95/100
# 36/36 [==============================] - 17s 480ms/step - loss: 0.4560 - accuracy: 0.7989 - val_loss: 0.4765 - val_accuracy: 0.7815
# Epoch 96/100
# 36/36 [==============================] - 16s 459ms/step - loss: 0.4540 - accuracy: 0.8015 - val_loss: 0.4773 - val_accuracy: 0.7779
# Epoch 97/100
# 36/36 [==============================] - 17s 469ms/step - loss: 0.4527 - accuracy: 0.7980 - val_loss: 0.4787 - val_accuracy: 0.7836
# Epoch 98/100
# 36/36 [==============================] - 18s 495ms/step - loss: 0.4559 - accuracy: 0.7965 - val_loss: 0.4749 - val_accuracy: 0.7851
# Epoch 99/100
# 36/36 [==============================] - 18s 496ms/step - loss: 0.4543 - accuracy: 0.7971 - val_loss: 0.4884 - val_accuracy: 0.7764
# Epoch 100/100
# 36/36 [==============================] - 19s 517ms/step - loss: 0.4581 - accuracy: 0.7930 - val_loss: 0.4776 - val_accuracy: 0.7795

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.summary()
# Out:
# Model: "perslay_model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_23 (Sequential)  (None, 1)                 401
#
# =================================================================
# Total params: 849
# Trainable params: 849
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# Second test with BettiCurve

# %%
perslay_parameters = []
perslay_channel = {}
perslay_channel["pweight_train"] = True
perslay_channel["layer_train"]   = True
perslay_channel["final_model"]   = "identity"

# %%
perslay_channel["layer"]           = "BettiCurve"
perslay_channel["theta"]           = 10
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0)

# %%
perslay_channel["pweight"]       = "power"
perslay_channel["pweight_init"]  = 1.
perslay_channel["pweight_power"] = 1

# %%
perslay_channel["perm_op"] = "sum"

# %%
perslay_parameters = [perslay_channel for _ in range(len(D))]

# %%
rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid")])
model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(x=[diags_train, feats_train], y=y_train, validation_data=([diags_test, feats_test], y_test), epochs=20, batch_size=128, shuffle=True, verbose=1)
# Out:
# Epoch 1/20
# 36/36 [==============================] - 22s 583ms/step - loss: 22.6293 - accuracy: 0.5119 - val_loss: 4.7371 - val_accuracy: 0.5313
# Epoch 2/20
# 36/36 [==============================] - 20s 548ms/step - loss: 1.9880 - accuracy: 0.5758 - val_loss: 0.9908 - val_accuracy: 0.6241
# Epoch 3/20
# 36/36 [==============================] - 20s 566ms/step - loss: 0.8704 - accuracy: 0.5747 - val_loss: 0.7310 - val_accuracy: 0.5677
# Epoch 4/20
# 36/36 [==============================] - 19s 536ms/step - loss: 0.6938 - accuracy: 0.6037 - val_loss: 0.6668 - val_accuracy: 0.6195
# Epoch 5/20
# 36/36 [==============================] - 19s 531ms/step - loss: 0.6621 - accuracy: 0.6191 - val_loss: 0.6287 - val_accuracy: 0.6344
# Epoch 6/20
# 36/36 [==============================] - 19s 533ms/step - loss: 0.6086 - accuracy: 0.6673 - val_loss: 0.5993 - val_accuracy: 0.6682
# Epoch 7/20
# 36/36 [==============================] - 20s 562ms/step - loss: 0.5941 - accuracy: 0.6855 - val_loss: 0.5916 - val_accuracy: 0.7062
# Epoch 8/20
# 36/36 [==============================] - 20s 558ms/step - loss: 0.5728 - accuracy: 0.7127 - val_loss: 0.5600 - val_accuracy: 0.7369
# Epoch 9/20
# 36/36 [==============================] - 19s 537ms/step - loss: 0.5510 - accuracy: 0.7310 - val_loss: 0.5783 - val_accuracy: 0.6918
# Epoch 10/20
# 36/36 [==============================] - 19s 538ms/step - loss: 0.5404 - accuracy: 0.7369 - val_loss: 0.5290 - val_accuracy: 0.7456
# Epoch 11/20
# 36/36 [==============================] - 20s 549ms/step - loss: 0.5436 - accuracy: 0.7327 - val_loss: 0.5243 - val_accuracy: 0.7456
# Epoch 12/20
# 36/36 [==============================] - 19s 535ms/step - loss: 0.5313 - accuracy: 0.7398 - val_loss: 0.5391 - val_accuracy: 0.7369
# Epoch 13/20
# 36/36 [==============================] - 19s 535ms/step - loss: 0.5389 - accuracy: 0.7380 - val_loss: 0.5277 - val_accuracy: 0.7349
# Epoch 14/20
# 36/36 [==============================] - 19s 531ms/step - loss: 0.5125 - accuracy: 0.7545 - val_loss: 0.5313 - val_accuracy: 0.7303
# Epoch 15/20
# 36/36 [==============================] - 20s 555ms/step - loss: 0.5031 - accuracy: 0.7637 - val_loss: 0.5071 - val_accuracy: 0.7590
# Epoch 16/20
# 36/36 [==============================] - 20s 567ms/step - loss: 0.5130 - accuracy: 0.7552 - val_loss: 0.5086 - val_accuracy: 0.7482
# Epoch 17/20
# 36/36 [==============================] - 20s 567ms/step - loss: 0.5231 - accuracy: 0.7486 - val_loss: 0.5390 - val_accuracy: 0.7292
# Epoch 18/20
# 36/36 [==============================] - 20s 545ms/step - loss: 0.5345 - accuracy: 0.7358 - val_loss: 0.5586 - val_accuracy: 0.7108
# Epoch 19/20
# 36/36 [==============================] - 19s 538ms/step - loss: 0.5102 - accuracy: 0.7596 - val_loss: 0.6214 - val_accuracy: 0.6821
# Epoch 20/20
# 36/36 [==============================] - 19s 528ms/step - loss: 0.5545 - accuracy: 0.7182 - val_loss: 0.5404 - val_accuracy: 0.7262

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Gridsearch for a first and quick comparison of the parameters.

# %%
from sklearn.model_selection import train_test_split
X_train0, X_test0, y_train, y_test = train_test_split(D[0], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train1, X_test1, y_train, y_test = train_test_split(D[1], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train2, X_test2, y_train, y_test = train_test_split(D[2], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train3, X_test3, y_train, y_test = train_test_split(D[3], gender_classes_bi_over, test_size=0.3, random_state=69)
feats_train, feats_test, y_train, y_test = train_test_split(F, gender_classes_bi_over, test_size=0.3, random_state=69)
diags_train = [X_train0,X_train1,X_train2,X_train3]
diags_test = [X_test0,X_test1,X_test2,X_test3]

# %%
histories =[]
models=[]
for optimizer in ["RMSprop","Nadam","adam"]:  
        perslay_parameters = []
        perslay_channel = {}
        perslay_channel["pweight_train"] = True
        perslay_channel["layer_train"]   = True
        perslay_channel["final_model"]   = "identity"
        for layer in ["BettiCurve","PermutationEquivariant","Exponential","Landscape"]:
            print(optimizer,layer)
            if layer =="BettiCurve":
                perslay_channel["layer"]           = "BettiCurve"
                perslay_channel["theta"]           = 10
                perslay_channel["lsample_num"]     = 100
                perslay_channel["lsample_init"]    = rui(0.0, 1.0) 
            if layer =="PermutationEquivariant":
                perslay_channel["layer"]           = "PermutationEquivariant"
                perslay_channel["lpeq"]            = [(5, "max")]
                perslay_channel["lweight_init"]    = rui(0.0, 1.0)
                perslay_channel["lbias_init"]      = rui(0.0, 1.0)
                perslay_channel["lgamma_init"]     = rui(0.0, 1.0)
            if layer =="Exponential":
                perslay_channel["layer"]           = "Exponential"
                perslay_channel["lnum"]            = 25
                perslay_channel["lmean_init"]      = rui(0.0, 1.0)
                perslay_channel["lvariance_init"]  = rui(3.0, 3.0)
            if layer =="Landscape":
                perslay_channel["layer"]           = "Landscape"
                perslay_channel["lsample_num"]     = 100
                perslay_channel["lsample_init"]    = rui(0.0, 1.0) 

            for pweight in ["power","grid","gmix","None"]:
                if pweight =="power":
                    perslay_channel["pweight"]       = "power"
                    perslay_channel["pweight_init"]  = 1.
                    perslay_channel["pweight_power"] = 1
                if pweight =="grid":
                    perslay_channel["pweight"]       = "grid"
                    perslay_channel["pweight_size"]  = [20,20]
                    perslay_channel["pweight_bnds"]  = ((-.001, 1.001), (-.001, 1.001))
                    perslay_channel["pweight_init"]  = rui(1.0, 1.0)
                if pweight =="gmix":
                    perslay_channel["pweight"]       = "gmix"
                    perslay_channel["pweight_num"]   = 3
                    perslay_channel["pweight_init"]  = np.array(np.vstack([np.random.uniform(0.,1.,[2,3]), 
                                                                            5.*np.ones([2,3])]), dtype=np.float32)
                if pweight =="None":
                    perslay_channel["pweight"]       = None

                for perm_op in ["perm_op","topk","max"]:
                    if perm_op =="perm_op":
                        perslay_channel["perm_op"] = "sum"
                    if perm_op =="topk":
                        perslay_channel["perm_op"] = "topk"
                        perslay_channel["keep"]    = 10
                    if perm_op =="max":
                        perslay_channel["perm_op"] = "max"
                    if (optimizer,perm_op,pweight,layer) in [('RMSprop', 'perm_op', 'power', 'Exponential')]:
                        continue  
                    try:
                        perslay_parameters = [perslay_channel for _ in range(len(D))]
                        rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid")])
                        model = None
                        model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
                        model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
                        history = model.fit(x=[diags_train, feats_train], y=y_train, validation_data=([diags_test, feats_test], y_test), epochs=5, batch_size=32, shuffle=True, verbose=0)
                        histories.append(history)
                        models.append(model)
                    except :
                        print(optimizer,perm_op,pweight,layer)
# Out:
# RMSprop BettiCurve
# RMSprop PermutationEquivariant
# RMSprop Exponential
# RMSprop topk power Exponential
# RMSprop max power Exponential
# RMSprop perm_op grid Exponential
# RMSprop topk grid Exponential
# RMSprop max grid Exponential
# RMSprop perm_op gmix Exponential
# RMSprop topk gmix Exponential
# RMSprop max gmix Exponential
# RMSprop perm_op None Exponential
# RMSprop topk None Exponential
# RMSprop max None Exponential
# RMSprop Landscape
# Nadam BettiCurve
# Nadam PermutationEquivariant
# Nadam Exponential
# Nadam perm_op power Exponential
# Nadam topk power Exponential
# Nadam max power Exponential
# Nadam perm_op grid Exponential
# Nadam topk grid Exponential
# Nadam max grid Exponential
# Nadam perm_op gmix Exponential
# Nadam topk gmix Exponential
# Nadam max gmix Exponential
# Nadam perm_op None Exponential
# Nadam topk None Exponential
# Nadam max None Exponential
# Nadam Landscape
# adam BettiCurve
# adam PermutationEquivariant
# adam Exponential
# adam perm_op power Exponential
# adam topk power Exponential
# adam max power Exponential
# adam perm_op grid Exponential
# adam topk grid Exponential
# adam max grid Exponential
# adam perm_op gmix Exponential
# adam topk gmix Exponential
# adam max gmix Exponential
# adam perm_op None Exponential
# adam topk None Exponential
# adam max None Exponential
# adam Landscape

# %%
models_names =[]
for optimizer in ["RMSprop","Nadam","adam"]:  
        for layer in ["BettiCurve","PermutationEquivariant","Landscape"]:
            for pweight in ["power","grid","gmix","None"]:
                for perm_op in ["perm_op","topk","max"]:
                    models_names.append(optimizer+"_"+perm_op+"_"+pweight+"_"+layer)

# %%
len(models_names)==len(histories)
# Out:
# True

# %%
models_description1
# Out:
# {'RMSprop_perm_op_power_BettiCurve': 0.5727179408073425,
#  'RMSprop_topk_power_BettiCurve': 0.7136410117149353,
#  'RMSprop_max_power_BettiCurve': 0.6602051377296447,
#  'RMSprop_perm_op_grid_BettiCurve': 0.5457435786724091,
#  'RMSprop_topk_grid_BettiCurve': 0.6672820568084716,
#  'RMSprop_max_grid_BettiCurve': 0.6867692351341248,
#  'RMSprop_perm_op_gmix_BettiCurve': 0.690666663646698,
#  'RMSprop_topk_gmix_BettiCurve': 0.6967179417610169,
#  'RMSprop_max_gmix_BettiCurve': 0.6937435865402222,
#  'RMSprop_perm_op_None_BettiCurve': 0.6019487261772156,
#  'RMSprop_topk_None_BettiCurve': 0.6402051210403442,
#  'RMSprop_max_None_BettiCurve': 0.6870769381523132,
#  'RMSprop_perm_op_power_PermutationEquivariant': 0.5129230797290802,
#  'RMSprop_topk_power_PermutationEquivariant': 0.7005128145217896,
#  'RMSprop_max_power_PermutationEquivariant': 0.5300512790679932,
#  'RMSprop_perm_op_grid_PermutationEquivariant': 0.5668717861175537,
#  'RMSprop_topk_grid_PermutationEquivariant': 0.6551794886589051,
#  'RMSprop_max_grid_PermutationEquivariant': 0.6347692370414734,
#  'RMSprop_perm_op_gmix_PermutationEquivariant': 0.5376410365104676,
#  'RMSprop_topk_gmix_PermutationEquivariant': 0.666564118862152,
#  'RMSprop_max_gmix_PermutationEquivariant': 0.6074871778488159,
#  'RMSprop_perm_op_None_PermutationEquivariant': 0.6431794881820678,
#  'RMSprop_topk_None_PermutationEquivariant': 0.5576410174369812,
#  'RMSprop_max_None_PermutationEquivariant': 0.6025640964508057,
#  'RMSprop_perm_op_power_Landscape': 0.5501538395881653,
#  'RMSprop_topk_power_Landscape': 0.6608205080032349,
#  'RMSprop_max_power_Landscape': 0.6451282024383544,
#  'RMSprop_perm_op_grid_Landscape': 0.5991795063018799,
#  'RMSprop_topk_grid_Landscape': 0.7165128111839294,
#  'RMSprop_max_grid_Landscape': 0.6687179446220398,
#  'RMSprop_perm_op_gmix_Landscape': 0.7291282057762146,
#  'RMSprop_topk_gmix_Landscape': 0.7076923012733459,
#  'RMSprop_max_gmix_Landscape': 0.6469743609428406,
#  'RMSprop_perm_op_None_Landscape': 0.5851282060146332,
#  'RMSprop_topk_None_Landscape': 0.691282057762146,
#  'RMSprop_max_None_Landscape': 0.6652307748794556,
#  'Nadam_perm_op_power_BettiCurve': 0.6033846139907837,
#  'Nadam_topk_power_BettiCurve': 0.7398974418640136,
#  'Nadam_max_power_BettiCurve': 0.6617435932159423,
#  'Nadam_perm_op_grid_BettiCurve': 0.5741538405418396,
#  'Nadam_topk_grid_BettiCurve': 0.7090256452560425,
#  'Nadam_max_grid_BettiCurve': 0.690461540222168,
#  'Nadam_perm_op_gmix_BettiCurve': 0.6292307734489441,
#  'Nadam_topk_gmix_BettiCurve': 0.6718974351882935,
#  'Nadam_max_gmix_BettiCurve': 0.6334358930587769,
#  'Nadam_perm_op_None_BettiCurve': 0.5710769176483155,
#  'Nadam_topk_None_BettiCurve': 0.6980512738227844,
#  'Nadam_max_None_BettiCurve': 0.6909743547439575,
#  'Nadam_perm_op_power_PermutationEquivariant': 0.5993846178054809,
#  'Nadam_topk_power_PermutationEquivariant': 0.7029743671417237,
#  'Nadam_max_power_PermutationEquivariant': 0.5558974266052246,
#  'Nadam_perm_op_grid_PermutationEquivariant': 0.6250256419181823,
#  'Nadam_topk_grid_PermutationEquivariant': 0.653948700428009,
#  'Nadam_max_grid_PermutationEquivariant': 0.6672820568084716,
#  'Nadam_perm_op_gmix_PermutationEquivariant': 0.6931282043457031,
#  'Nadam_topk_gmix_PermutationEquivariant': 0.6762051224708557,
#  'Nadam_max_gmix_PermutationEquivariant': 0.6485128164291382,
#  'Nadam_perm_op_None_PermutationEquivariant': 0.7172307729721069,
#  'Nadam_topk_None_PermutationEquivariant': 0.644820511341095,
#  'Nadam_max_None_PermutationEquivariant': 0.5990769386291503,
#  'Nadam_perm_op_power_Landscape': 0.6090256452560425,
#  'Nadam_topk_power_Landscape': 0.6624615311622619,
#  'Nadam_max_power_Landscape': 0.6374358892440796,
#  'Nadam_perm_op_grid_Landscape': 0.6481025576591491,
#  'Nadam_topk_grid_Landscape': 0.7131281971931458,
#  'Nadam_max_grid_Landscape': 0.6664615392684936,
#  'Nadam_perm_op_gmix_Landscape': 0.7422564148902893,
#  'Nadam_topk_gmix_Landscape': 0.737948727607727,
#  'Nadam_max_gmix_Landscape': 0.6841025471687316,
#  'Nadam_perm_op_None_Landscape': 0.6286153852939605,
#  'Nadam_topk_None_Landscape': 0.7051282048225402,
#  'Nadam_max_None_Landscape': 0.6689230799674988,
#  'adam_perm_op_power_BettiCurve': 0.66328204870224,
#  'adam_topk_power_BettiCurve': 0.753948712348938,
#  'adam_max_power_BettiCurve': 0.6621538400650024,
#  'adam_perm_op_grid_BettiCurve': 0.7042051315307617,
#  'adam_topk_grid_BettiCurve': 0.7299487233161926,
#  'adam_max_grid_BettiCurve': 0.6978461384773255,
#  'adam_perm_op_gmix_BettiCurve': 0.6747692227363586,
#  'adam_topk_gmix_BettiCurve': 0.7012307643890381,
#  'adam_max_gmix_BettiCurve': 0.680923068523407,
#  'adam_perm_op_None_BettiCurve': 0.7173333406448364,
#  'adam_topk_None_BettiCurve': 0.7091282129287719,
#  'adam_max_None_BettiCurve': 0.6835897564888,
#  'adam_perm_op_power_PermutationEquivariant': 0.6156923115253449,
#  'adam_topk_power_PermutationEquivariant': 0.7330256223678588,
#  'adam_max_power_PermutationEquivariant': 0.5313846111297608,
#  'adam_perm_op_grid_PermutationEquivariant': 0.5654358983039856,
#  'adam_topk_grid_PermutationEquivariant': 0.6652307748794556,
#  'adam_max_grid_PermutationEquivariant': 0.6617435932159423,
#  'adam_perm_op_gmix_PermutationEquivariant': 0.6093333482742309,
#  'adam_topk_gmix_PermutationEquivariant': 0.7039999961853027,
#  'adam_max_gmix_PermutationEquivariant': 0.6846153855323791,
#  'adam_perm_op_None_PermutationEquivariant': 0.6114871621131897,
#  'adam_topk_None_PermutationEquivariant': 0.5734358847141265,
#  'adam_max_None_PermutationEquivariant': 0.6715897560119629,
#  'adam_perm_op_power_Landscape': 0.6241025686264038,
#  'adam_topk_power_Landscape': 0.6658461451530456,
#  'adam_max_power_Landscape': 0.6471794962882995,
#  'adam_perm_op_grid_Landscape': 0.7068717956542969,
#  'adam_topk_grid_Landscape': 0.725743579864502,
#  'adam_max_grid_Landscape': 0.666153860092163,
#  'adam_perm_op_gmix_Landscape': 0.7302564144134521,
#  'adam_topk_gmix_Landscape': 0.7166153907775878,
#  'adam_max_gmix_Landscape': 0.6531282186508178,
#  'adam_perm_op_None_Landscape': 0.6725128293037415,
#  'adam_topk_None_Landscape': 0.7075897455215454,
#  'adam_max_None_Landscape': 0.6663589596748352}

# %%
models_description1 = dict(zip(models_names, [np.mean(histo.history['val_accuracy']) for histo in histories]))
models_description2 = dict(zip(models_names, [np.max(histo.history['val_accuracy']) for histo in histories]))
models_description1 = pd.Series(models_description1)
models_description2 = pd.Series(models_description2)
df_models = pd.concat([models_description1,models_description2], axis=1)
df_models = df_models.rename(columns={0: "mean", 1: "max"})
df_models = df_models.reset_index()
df_models.head()
# Out:
#                               index      mean       max
# 0  RMSprop_perm_op_power_BettiCurve  0.572718  0.629744
# 1     RMSprop_topk_power_BettiCurve  0.713641  0.774872
# 2      RMSprop_max_power_BettiCurve  0.660205  0.666154
# 3   RMSprop_perm_op_grid_BettiCurve  0.545744  0.694872
# 4      RMSprop_topk_grid_BettiCurve  0.667282  0.706154

# %%
plt.figure(figsize=(16, 12))
sns.barplot(data=df_models.sort_values(by='mean', ascending=False).head(10),x='mean', y='index');
plt.show();

# %%
plt.figure(figsize=(16, 12))
sns.barplot(data=df_models.sort_values(by='max', ascending=False).head(10),x='max', y='index');
plt.show();

# %%
optimizer,perm_op,pweight,layer
# Out:
# ('RMSprop', 'perm_op', 'power', 'Exponential')

# %%
for history in histories:
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    #plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
for history in histories:
    # summarize history for accuracy
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')

    #plt.legend(['train', 'test'], loc='upper left')
plt.show()# summarize history for loss

# %%
#nqd topk poer betticurve
# best one

# %%
from sklearn.model_selection import train_test_split
X_train0, X_test0, y_train, y_test = train_test_split(D[0], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train1, X_test1, y_train, y_test = train_test_split(D[1], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train2, X_test2, y_train, y_test = train_test_split(D[2], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train3, X_test3, y_train, y_test = train_test_split(D[3], gender_classes_bi_over, test_size=0.3, random_state=69)
feats_train, feats_test, y_train, y_test = train_test_split(F, gender_classes_bi_over, test_size=0.3, random_state=69)
diags_train = [X_train0,X_train1,X_train2,X_train3]
diags_test = [X_test0,X_test1,X_test2,X_test3]

# %%
optimizer = "Nadam"
perslay_parameters = []
perslay_channel = {}
perslay_channel["pweight_train"] = True
perslay_channel["layer_train"]   = True
perslay_channel["final_model"]   = "identity"
perslay_channel["layer"]           = "BettiCurve"
perslay_channel["theta"]           = 10
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0) 
perslay_channel["pweight"]       = "power"
perslay_channel["pweight_init"]  = 1.
perslay_channel["pweight_power"] = 1
perslay_channel["perm_op"] = "topk"
perslay_channel["keep"]    = 10

perslay_parameters = [perslay_channel for _ in range(len(D))]
rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid")])
model = None
model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history = model.fit(x=[diags_train, feats_train], y=y_train, validation_data=([diags_test, feats_test], y_test), epochs=30, batch_size=64, shuffle=True, verbose=1)
# Out:
# Epoch 1/30
# 72/72 [==============================] - 28s 329ms/step - loss: 0.5187 - accuracy: 0.7596 - val_loss: 0.4944 - val_accuracy: 0.7615
# Epoch 2/30
# 72/72 [==============================] - 23s 316ms/step - loss: 0.4474 - accuracy: 0.8077 - val_loss: 0.4387 - val_accuracy: 0.8092
# Epoch 3/30
# 72/72 [==============================] - 23s 316ms/step - loss: 0.4309 - accuracy: 0.8141 - val_loss: 0.4284 - val_accuracy: 0.8256
# Epoch 4/30
# 72/72 [==============================] - 23s 326ms/step - loss: 0.4224 - accuracy: 0.8167 - val_loss: 0.4229 - val_accuracy: 0.8272
# Epoch 5/30
# 72/72 [==============================] - 23s 322ms/step - loss: 0.4140 - accuracy: 0.8178 - val_loss: 0.4124 - val_accuracy: 0.8205
# Epoch 6/30
# 72/72 [==============================] - 23s 316ms/step - loss: 0.4089 - accuracy: 0.8209 - val_loss: 0.4219 - val_accuracy: 0.8221
# Epoch 7/30
# 72/72 [==============================] - 23s 320ms/step - loss: 0.4059 - accuracy: 0.8204 - val_loss: 0.4331 - val_accuracy: 0.8246
# Epoch 8/30
# 72/72 [==============================] - 23s 316ms/step - loss: 0.4063 - accuracy: 0.8215 - val_loss: 0.4319 - val_accuracy: 0.8031
# Epoch 9/30
# 72/72 [==============================] - 24s 330ms/step - loss: 0.4039 - accuracy: 0.8224 - val_loss: 0.4249 - val_accuracy: 0.8226
# Epoch 10/30
# 72/72 [==============================] - 24s 329ms/step - loss: 0.4023 - accuracy: 0.8222 - val_loss: 0.4129 - val_accuracy: 0.8251
# Epoch 11/30
# 72/72 [==============================] - 24s 328ms/step - loss: 0.4012 - accuracy: 0.8237 - val_loss: 0.4313 - val_accuracy: 0.8072
# Epoch 12/30
# 72/72 [==============================] - 23s 313ms/step - loss: 0.3992 - accuracy: 0.8240 - val_loss: 0.4100 - val_accuracy: 0.8210
# Epoch 13/30
# 72/72 [==============================] - 23s 317ms/step - loss: 0.3994 - accuracy: 0.8218 - val_loss: 0.4005 - val_accuracy: 0.8277
# Epoch 14/30
# 72/72 [==============================] - 22s 313ms/step - loss: 0.3991 - accuracy: 0.8233 - val_loss: 0.4135 - val_accuracy: 0.8256
# Epoch 15/30
# 72/72 [==============================] - 24s 328ms/step - loss: 0.3966 - accuracy: 0.8255 - val_loss: 0.3985 - val_accuracy: 0.8313
# Epoch 16/30
# 72/72 [==============================] - 23s 316ms/step - loss: 0.3965 - accuracy: 0.8270 - val_loss: 0.4562 - val_accuracy: 0.7877
# Epoch 17/30
# 72/72 [==============================] - 23s 314ms/step - loss: 0.3990 - accuracy: 0.8233 - val_loss: 0.3985 - val_accuracy: 0.8256
# Epoch 18/30
# 72/72 [==============================] - 22s 306ms/step - loss: 0.3945 - accuracy: 0.8231 - val_loss: 0.3964 - val_accuracy: 0.8313
# Epoch 19/30
# 72/72 [==============================] - 22s 305ms/step - loss: 0.3957 - accuracy: 0.8268 - val_loss: 0.3961 - val_accuracy: 0.8272
# Epoch 20/30
# 72/72 [==============================] - 22s 307ms/step - loss: 0.3951 - accuracy: 0.8257 - val_loss: 0.4432 - val_accuracy: 0.7938
# Epoch 21/30
# 72/72 [==============================] - 22s 307ms/step - loss: 0.3943 - accuracy: 0.8270 - val_loss: 0.3952 - val_accuracy: 0.8318
# Epoch 22/30
# 72/72 [==============================] - 22s 312ms/step - loss: 0.3937 - accuracy: 0.8270 - val_loss: 0.3957 - val_accuracy: 0.8297
# Epoch 23/30
# 72/72 [==============================] - 22s 309ms/step - loss: 0.3916 - accuracy: 0.8222 - val_loss: 0.4072 - val_accuracy: 0.8292
# Epoch 24/30
# 72/72 [==============================] - 23s 314ms/step - loss: 0.3926 - accuracy: 0.8242 - val_loss: 0.3966 - val_accuracy: 0.8308
# Epoch 25/30
# 72/72 [==============================] - 22s 308ms/step - loss: 0.3916 - accuracy: 0.8257 - val_loss: 0.4064 - val_accuracy: 0.8292
# Epoch 26/30
# 72/72 [==============================] - 22s 307ms/step - loss: 0.3922 - accuracy: 0.8281 - val_loss: 0.4110 - val_accuracy: 0.8277
# Epoch 27/30
# 72/72 [==============================] - 22s 308ms/step - loss: 0.3932 - accuracy: 0.8299 - val_loss: 0.3980 - val_accuracy: 0.8303
# Epoch 28/30
# 72/72 [==============================] - 22s 307ms/step - loss: 0.3924 - accuracy: 0.8295 - val_loss: 0.4016 - val_accuracy: 0.8308
# Epoch 29/30
# 72/72 [==============================] - 22s 307ms/step - loss: 0.3910 - accuracy: 0.8284 - val_loss: 0.3942 - val_accuracy: 0.8308
# Epoch 30/30
# 72/72 [==============================] - 22s 304ms/step - loss: 0.3916 - accuracy: 0.8264 - val_loss: 0.3939 - val_accuracy: 0.8318

# %%
plt.plot(history.history['accuracy'],label="train accuracy")
plt.plot(history.history['val_accuracy'],label="validation accuracy")
plt.title('Perslay layer accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()
plt.savefig('Perslay_1_layer_accuracy.png')

# %%
np.max(history.history['val_accuracy'])
# Out:
# 0.8317948579788208

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Now we use Perslay but with images as features :

# %%
optimizer = "Nadam"
perslay_parameters = []
perslay_channel = {}

#perslay_channel["pweight"]       = "power"
#perslay_channel["pweight_init"]  = 1.
#perslay_channel["pweight_power"] = 1
#perslay_channel["perm_op"] = "topk"
#perslay_channel["keep"]    = 10


perslay_channel["layer_train"]    = True
perslay_channel["layer"]           = "BettiCurve"
perslay_channel["theta"]           = 10
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0) 
perslay_channel["pweight"]        = "grid"
perslay_channel["pweight_init"]   = rui(1., 1.)
perslay_channel["pweight_size"]   = (10, 10)
perslay_channel["pweight_bnds"]   = ((-0.001, 1.001), (-0.001, 1.001))
perslay_channel["pweight_train"]  = True
perslay_channel["perm_op"]        = "sum"

# fmodel = tf.keras.Sequential([tf.keras.layers.Conv2D(64, kernel_size=3, activation="relu"),
# tf.keras.layers.Conv2D(32, kernel_size=3, activation="relu"),
# tf.keras.layers.Flatten()])
#perslay_channel["final_model"]   = fmodel

perslay_parameters = [perslay_channel for _ in range(len(D))]




# optimizer = tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-4)
# optimizer = tfa.optimizers.MovingAverage(optimizer, average_decay=0.9) 
# loss = tf.keras.losses.CategoricalCrossentropy()
# metrics = [tf.keras.metrics.CategoricalAccuracy()]

for i in range(len(D)):
    fmodel =  tf.keras.Sequential([ 
    tf.keras.layers.Dense(64,activation='relu')])
    perslay_parameters[i]["final_model"] = fmodel


rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid")]) #2
model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split
X_train0, X_test0, y_train, y_test = train_test_split(D[0], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train1, X_test1, y_train, y_test = train_test_split(D[1], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train2, X_test2, y_train, y_test = train_test_split(D[2], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train3, X_test3, y_train, y_test = train_test_split(D[3], gender_classes_bi_over, test_size=0.3, random_state=69)
feats_train, feats_test, y_train, y_test = train_test_split( np.array([img.flatten() for img in images_over]), gender_classes_bi_over, test_size=0.3, random_state=69)
diags_train = [X_train0,X_train1,X_train2,X_train3]
diags_test = [X_test0,X_test1,X_test2,X_test3]

# %%
optimizer = "Nadam"

perslay_parameters = []
perslay_channel = {}
perslay_channel["pweight"]        = "grid"
perslay_channel["pweight_init"]   = rui(1., 1.)
perslay_channel["pweight_size"]   = (10, 10)
perslay_channel["pweight_bnds"]   = ((-0.001, 1.001), (-0.001, 1.001))
perslay_channel["pweight_train"]  = True
perslay_channel["layer"]          = "Image"
perslay_channel["image_size"]     = (20, 20)
perslay_channel["image_bnds"]     = ((-0.001, 1.001), (-0.001, 1.001))
perslay_channel["lvariance_init"] = rui(3., 3.)
perslay_channel["layer_train"]    = True
perslay_channel["perm_op"]        = "sum"
perslay_parameters = [perslay_channel for _ in range(len(D))]


for i in range(len(D)):
    fmodel = tf.keras.Sequential([tf.keras.layers.Conv2D(10, 2, input_shape=(21,21,1)), tf.keras.layers.Flatten()])
    perslay_parameters[i]["final_model"] = fmodel
rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid", input_shape=(16000+feats_train.shape[1],))])#1



model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
history = model.fit(x=[diags_train, feats_train], y=y_train, validation_data=([diags_test, feats_test], y_test), epochs=30, batch_size=64, shuffle=True, verbose=1)
# Out:
# Epoch 1/30
# 72/72 [==============================] - 122s 2s/step - loss: 4.4309 - accuracy: 0.6767 - val_loss: 7.0923 - val_accuracy: 0.5467
# Epoch 2/30
# 72/72 [==============================] - 116s 2s/step - loss: 2.7727 - accuracy: 0.7418 - val_loss: 17.4258 - val_accuracy: 0.5046
# Epoch 3/30
# 72/72 [==============================] - 113s 2s/step - loss: 2.0145 - accuracy: 0.7800 - val_loss: 1.9179 - val_accuracy: 0.7574
# Epoch 4/30
# 72/72 [==============================] - 116s 2s/step - loss: 1.9850 - accuracy: 0.7736 - val_loss: 0.9212 - val_accuracy: 0.8462
# Epoch 5/30
# 72/72 [==============================] - 115s 2s/step - loss: 1.6162 - accuracy: 0.7930 - val_loss: 1.5649 - val_accuracy: 0.7826
# Epoch 6/30
# 72/72 [==============================] - 115s 2s/step - loss: 1.1673 - accuracy: 0.8097 - val_loss: 0.7900 - val_accuracy: 0.8282
# Epoch 7/30
# 72/72 [==============================] - 117s 2s/step - loss: 1.2109 - accuracy: 0.8297 - val_loss: 0.7305 - val_accuracy: 0.8426
# Epoch 8/30
# 72/72 [==============================] - 113s 2s/step - loss: 0.8388 - accuracy: 0.8488 - val_loss: 1.9353 - val_accuracy: 0.7138
# Epoch 9/30
# 72/72 [==============================] - 114s 2s/step - loss: 0.8247 - accuracy: 0.8615 - val_loss: 4.9527 - val_accuracy: 0.5656
# Epoch 10/30
# 72/72 [==============================] - 111s 2s/step - loss: 0.6369 - accuracy: 0.8787 - val_loss: 1.6165 - val_accuracy: 0.7656
# Epoch 11/30
# 72/72 [==============================] - 113s 2s/step - loss: 0.6310 - accuracy: 0.8787 - val_loss: 0.7047 - val_accuracy: 0.8518
# Epoch 12/30
# 72/72 [==============================] - 113s 2s/step - loss: 0.3552 - accuracy: 0.9369 - val_loss: 0.8621 - val_accuracy: 0.8482
# Epoch 13/30
# 72/72 [==============================] - 112s 2s/step - loss: 0.0676 - accuracy: 0.9754 - val_loss: 0.7839 - val_accuracy: 0.8256
# Epoch 14/30
# 72/72 [==============================] - 112s 2s/step - loss: 0.6352 - accuracy: 0.9048 - val_loss: 1.3457 - val_accuracy: 0.7887
# Epoch 15/30
# 72/72 [==============================] - 112s 2s/step - loss: 0.4955 - accuracy: 0.9196 - val_loss: 0.7189 - val_accuracy: 0.8528
# Epoch 16/30
# 72/72 [==============================] - 111s 2s/step - loss: 0.0331 - accuracy: 0.9892 - val_loss: 0.6487 - val_accuracy: 0.8497
# Epoch 17/30
# 72/72 [==============================] - 112s 2s/step - loss: 0.0179 - accuracy: 0.9956 - val_loss: 0.6329 - val_accuracy: 0.8518
# Epoch 18/30
# 72/72 [==============================] - 112s 2s/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.6238 - val_accuracy: 0.8492
# Epoch 19/30
# 72/72 [==============================] - 110s 2s/step - loss: 0.0114 - accuracy: 0.9982 - val_loss: 0.6161 - val_accuracy: 0.8497
# Epoch 20/30
# 72/72 [==============================] - 110s 2s/step - loss: 0.0104 - accuracy: 0.9996 - val_loss: 0.6431 - val_accuracy: 0.8467
# Epoch 21/30
# 72/72 [==============================] - 115s 2s/step - loss: 0.0089 - accuracy: 0.9998 - val_loss: 0.6163 - val_accuracy: 0.8513
# Epoch 22/30
# 72/72 [==============================] - 109s 2s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.6099 - val_accuracy: 0.8497
# Epoch 23/30
# 72/72 [==============================] - 112s 2s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.6113 - val_accuracy: 0.8508
# Epoch 24/30
# 72/72 [==============================] - 109s 2s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.6686 - val_accuracy: 0.8482
# Epoch 25/30
# 72/72 [==============================] - 113s 2s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.6893 - val_accuracy: 0.8251
# Epoch 26/30
# 72/72 [==============================] - 112s 2s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.6094 - val_accuracy: 0.8538
# Epoch 27/30
# 72/72 [==============================] - 110s 2s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.6140 - val_accuracy: 0.8518
# Epoch 28/30
# 72/72 [==============================] - 115s 2s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.6222 - val_accuracy: 0.8451
# Epoch 29/30
# 72/72 [==============================] - 117s 2s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.6065 - val_accuracy: 0.8497
# Epoch 30/30
# 72/72 [==============================] - 116s 2s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.6080 - val_accuracy: 0.8503

# %%
np.max(history.history['val_accuracy'])
# Out:
# 0.8538461327552795

# %%
plt.plot(history.history['accuracy'],label="train accuracy")
plt.plot(history.history['val_accuracy'],label="validation accuracy")
plt.title('Perslay layer with features accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()
plt.savefig('Perslay_with_features_layer_accuracy.png')

# %%
from sklearn.model_selection import train_test_split
X_train0, X_test0, y_train, y_test = train_test_split(D[0], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train1, X_test1, y_train, y_test = train_test_split(D[1], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train2, X_test2, y_train, y_test = train_test_split(D[2], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train3, X_test3, y_train, y_test = train_test_split(D[3], gender_classes_bi_over, test_size=0.3, random_state=69)
feats_train, feats_test, y_train, y_test = train_test_split( np.array([img.flatten() for img in images_over]), gender_classes_bi_over, test_size=0.3, random_state=69)
diags_train = [X_train0,X_train1,X_train2,X_train3]
diags_test = [X_test0,X_test1,X_test2,X_test3]

# %%
perslay_parameters = []
perslay_channel = {}
perslay_channel["pweight_train"] = True
perslay_channel["layer_train"]   = True

perslay_channel["layer"]           = "BettiCurve"
perslay_channel["theta"]           = 10
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0) 
perslay_channel["pweight"]       = "power"
perslay_channel["pweight_init"]  = 1.
perslay_channel["pweight_power"] = 1
perslay_channel["perm_op"] = "topk"
perslay_channel["keep"]    = 10


# fmodel = tf.keras.Sequential([tf.keras.layers.Conv2D(64, kernel_size=3, activation="relu"),
# tf.keras.layers.Conv2D(32, kernel_size=3, activation="relu"),
# tf.keras.layers.Flatten()])
#perslay_channel["final_model"]   = fmodel
perslay_parameters = [perslay_channel for _ in range(len(D))]


for i in range(len(D)):
    fmodel =  tf.keras.Sequential([ tf.keras.layers.Conv2D(kernel_size=(4,4), filters=32, activation='selu'),
    tf.keras.layers.MaxPool2D(5,5),
    tf.keras.layers.Conv2D(filters=64,kernel_size = (3,3),activation='selu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(filters=128,kernel_size = (3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64,activation='relu')])
    perslay_parameters[i]["final_model"] = fmodel

rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid")]) #2
model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
input_images = Input(shape=(256, 256,1,))
x = Conv2D(kernel_size=(4,4), filters=32, activation='selu')(input_images)
x = MaxPool2D(5,5)(x)
x = Conv2D(filters=64,kernel_size = (3,3),activation='selu')(x)
x = MaxPool2D(2,2)(x)
x = Conv2D(filters=128,kernel_size = (3,3),activation='relu')(x)
x = MaxPool2D(2,2)(x)
x = Flatten()(x)
x = Dense(64,activation='relu')(x)
x = Model(inputs=input_images, outputs=x)

#second model #two options (images or not)
input_features = Input(shape=(84,))
y = Dense(84,activation='relu')(input_features)
y = Dense(64,activation='relu')(y)
y = Model(inputs=input_features, outputs=y)

# combine the output of the two branches
combined = concatenate([x.output, y.output])
# apply a FC layer and then a regression prediction on the
# combined outputs




z = Dense(32,activation=tf.keras.layers.LeakyReLU(alpha=0.3))(combined)
z = Dropout(0.2)(z)
z= Dense(1,activation = 'sigmoid')(z)
model_66 = Model(inputs=[x.input, y.input], outputs=z)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model_66, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model_66.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_5 (Conv2D)              (None, 253, 253, 32  544         ['input_4[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 50, 50, 32)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 64)   18496       ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 24, 24, 64)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 22, 22, 128)  73856       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 11, 11, 128)  0          ['conv2d_7[0][0]']
#
#  input_5 (InputLayer)           [(None, 84)]         0           []
#
#  flatten_1 (Flatten)            (None, 15488)        0           ['max_pooling2d_5[0][0]']
#
#  dense_3 (Dense)                (None, 84)           7140        ['input_5[0][0]']
#
#  dense_2 (Dense)                (None, 64)           991296      ['flatten_1[0][0]']
#
#  dense_4 (Dense)                (None, 64)           5440        ['dense_3[0][0]']
#
#  concatenate (Concatenate)      (None, 128)          0           ['dense_2[0][0]',
#                                                                   'dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 32)           4128        ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 1)            33          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,100,933
# Trainable params: 1,100,933
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# to continue (last result is adding PersLay as a feature augmentation method)

# %%
F = np.array([img.flatten() for img in images_over])

# %%
from sklearn.model_selection import train_test_split
X_train0, X_test0, y_train, y_test = train_test_split(D[0], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train1, X_test1, y_train, y_test = train_test_split(D[1], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train2, X_test2, y_train, y_test = train_test_split(D[2], gender_classes_bi_over, test_size=0.3, random_state=69)
X_train3, X_test3, y_train, y_test = train_test_split(D[3], gender_classes_bi_over, test_size=0.3, random_state=69)
feats_train, feats_test, y_train, y_test = train_test_split(F, gender_classes_bi_over, test_size=0.3, random_state=69)
# Images_train, Images_test, y_train, y_test = train_test_split(F, gender_classes_bi_over, test_size=0.3, random_state=69)

diags_train = [X_train0,X_train1,X_train2,X_train3]
diags_test = [X_test0,X_test1,X_test2,X_test3]

# %%
optimizer = "Nadam"
perslay_parameters = []
perslay_channel = {}
perslay_channel["pweight_train"] = True
perslay_channel["layer_train"]   = True
perslay_channel["final_model"]   = "identity"
perslay_channel["layer"]           = "BettiCurve"
perslay_channel["theta"]           = 10
perslay_channel["lsample_num"]     = 100
perslay_channel["lsample_init"]    = rui(0.0, 1.0) 
perslay_channel["pweight"]       = "power"
perslay_channel["pweight_init"]  = 1.
perslay_channel["pweight_power"] = 1
perslay_channel["perm_op"] = "topk"
perslay_channel["keep"]    = 10

perslay_parameters = [perslay_channel for _ in range(len(D))]

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,MaxPool2D
from keras.layers import Activation, Dropout, Flatten, Dense, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
rho = tf.keras.Sequential([tf.keras.layers.Dense(1, activation="sigmoid")])
model = None
model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)

# %%
model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
history = model.fit(x=[diags_train, feats_train], y=y_train, validation_data=([diags_test, feats_test], y_test), epochs=30, batch_size=32, shuffle=True, verbose=1)
# Out:
# Epoch 1/30
# 143/143 [==============================] - 30s 182ms/step - loss: 1.8436 - accuracy: 0.7033 - val_loss: 1.0961 - val_accuracy: 0.7831
# Epoch 2/30
# 143/143 [==============================] - 27s 190ms/step - loss: 1.6356 - accuracy: 0.7585 - val_loss: 1.4003 - val_accuracy: 0.7518
# Epoch 3/30
# 143/143 [==============================] - 28s 199ms/step - loss: 1.1831 - accuracy: 0.8009 - val_loss: 0.9957 - val_accuracy: 0.8067
# Epoch 4/30
# 143/143 [==============================] - 26s 180ms/step - loss: 0.6460 - accuracy: 0.8609 - val_loss: 1.4758 - val_accuracy: 0.7082
# Epoch 5/30
# 143/143 [==============================] - 26s 185ms/step - loss: 0.8724 - accuracy: 0.8519 - val_loss: 2.7270 - val_accuracy: 0.6821
# Epoch 6/30
# 143/143 [==============================] - 26s 180ms/step - loss: 0.6521 - accuracy: 0.8723 - val_loss: 1.2666 - val_accuracy: 0.7928
# Epoch 7/30
# 143/143 [==============================] - 25s 179ms/step - loss: 0.1720 - accuracy: 0.9495 - val_loss: 0.8502 - val_accuracy: 0.7841
# Epoch 8/30
# 143/143 [==============================] - 26s 185ms/step - loss: 0.2591 - accuracy: 0.9455 - val_loss: 1.0171 - val_accuracy: 0.8318
# Epoch 9/30
# 143/143 [==============================] - 27s 189ms/step - loss: 0.4631 - accuracy: 0.9257 - val_loss: 0.7500 - val_accuracy: 0.8451
# Epoch 10/30
# 143/143 [==============================] - 25s 177ms/step - loss: 0.0341 - accuracy: 0.9870 - val_loss: 0.6721 - val_accuracy: 0.8369
# Epoch 11/30
# 143/143 [==============================] - 25s 177ms/step - loss: 0.0170 - accuracy: 0.9954 - val_loss: 0.6278 - val_accuracy: 0.8456
# Epoch 12/30
# 143/143 [==============================] - 26s 179ms/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.6005 - val_accuracy: 0.8385
# Epoch 13/30
# 143/143 [==============================] - 25s 177ms/step - loss: 0.0065 - accuracy: 0.9998 - val_loss: 0.6343 - val_accuracy: 0.8431
# Epoch 14/30
# 143/143 [==============================] - 26s 184ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.5923 - val_accuracy: 0.8431
# Epoch 15/30
# 143/143 [==============================] - 26s 180ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.6045 - val_accuracy: 0.8441
# Epoch 16/30
# 143/143 [==============================] - 25s 178ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.6019 - val_accuracy: 0.8446
# Epoch 17/30
# 143/143 [==============================] - 25s 178ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5848 - val_accuracy: 0.8426
# Epoch 18/30
# 143/143 [==============================] - 28s 195ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5985 - val_accuracy: 0.8436
# Epoch 19/30
# 143/143 [==============================] - 26s 181ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5876 - val_accuracy: 0.8415
# Epoch 20/30
# 143/143 [==============================] - 25s 175ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6020 - val_accuracy: 0.8431
# Epoch 21/30
# 143/143 [==============================] - 27s 186ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5972 - val_accuracy: 0.8426
# Epoch 22/30
# 143/143 [==============================] - 25s 177ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5914 - val_accuracy: 0.8415
# Epoch 23/30
# 143/143 [==============================] - 26s 183ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5993 - val_accuracy: 0.8436
# Epoch 24/30
# 143/143 [==============================] - 27s 187ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6005 - val_accuracy: 0.8405
# Epoch 25/30
# 143/143 [==============================] - 26s 184ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6376 - val_accuracy: 0.8426
# Epoch 26/30
# 143/143 [==============================] - 26s 180ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5957 - val_accuracy: 0.8436
# Epoch 27/30
# 143/143 [==============================] - 27s 190ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5979 - val_accuracy: 0.8426
# Epoch 28/30
# 143/143 [==============================] - 26s 183ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5988 - val_accuracy: 0.8451
# Epoch 29/30
# 143/143 [==============================] - 25s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6262 - val_accuracy: 0.8446
# Epoch 30/30
# 143/143 [==============================] - 26s 183ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6023 - val_accuracy: 0.8451

# %%
plt.plot(history.history['accuracy'],label="train accuracy")
plt.plot(history.history['val_accuracy'],label="validation accuracy")
plt.title('Perslay layer accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()
plt.savefig('Perslay_1_layer_accuracy.png')

# %%
rho = tf.keras.Sequential([Dense(64,activation='relu')(y)])
perslayModel = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)

# %%
input_images = Input(shape=(256, 256,1,))
x = Conv2D(kernel_size=(4,4), filters=32, activation='selu')(input_images)
x = MaxPool2D(5,5)(x)
x = Conv2D(filters=64,kernel_size = (3,3),activation='selu')(x)
x = MaxPool2D(2,2)(x)
x = Conv2D(filters=128,kernel_size = (3,3),activation='relu')(x)
x = MaxPool2D(2,2)(x)
x = Flatten()(x)
x = Dense(64,activation='relu')(x)
x = Model(inputs=input_images, outputs=x)

#second model #two options (images or not)
input_features = Input(shape=(84,))
rho = tf.keras.Sequential([Dense(64,activation='relu')(input_features)])
perslayModel = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
y = Model(inputs=input_features, outputs=perslayModel)



# combine the output of the two branches
combined = concatenate([x.output, y.output])
# apply a FC layer and then a regression prediction on the
# combined outputs




z = Dense(32,activation=tf.keras.layers.LeakyReLU(alpha=0.3))(combined)
z = Dropout(0.2)(z)
z= Dense(1,activation = 'sigmoid')(z)
model_66 = Model(inputs=[x.input, y.input], outputs=z)

# %%
plp = {}
plp["pweight"]        = "grid"
plp["pweight_init"]   = rui(1., 1.)
plp["pweight_size"]   = (10, 10)
plp["pweight_bnds"]   = ((-0.001, 1.001), (-0.001, 1.001))
plp["pweight_train"]  = True
plp["layer"]          = "PermutationEquivariant"
plp["lpeq"]           = [(25, None), (25, "max")]
plp["lweight_init"]   = rui(0.,1.)
plp["lbias_init"]     = rui(0.,1.)
plp["lgamma_init"]    = rui(0.,1.)
plp["layer_train"]    = True
plp["perm_op"]        = "topk"
plp["keep"]           = 5
plp["final_model"]    = "identity"
perslay_parameters    = [plp for _ in range(2)]

mirrored_strategy = tf.distribute.MirroredStrategy()
with mirrored_strategy.scope():
    rho = tf.keras.Sequential([tf.keras.layers.Dense(5, activation="sigmoid", input_shape=(250+nf,))])
    model = PerslayModel(name="PersLay", diagdim=2, perslay_parameters=perslay_parameters, rho=rho)
    lr = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=0.01, decay_steps=20, decay_rate=1., staircase=True)
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr, epsilon=1e-4)
    optimizer = tfa.optimizers.MovingAverage(optimizer, average_decay=0.9) 
    loss = tf.keras.losses.CategoricalCrossentropy()
    metrics = [tf.keras.metrics.CategoricalAccuracy()]

# %% [markdown]
# # Bibliography

# %% [markdown]
#  _PersLay: A Simple and Versatile Neural Network Layer for Persistence Diagrams._
# Mathieu Carrière, Frederic Chazal, Yuichi Ike, Théo Lacombe, Martin Royer, Yuhei Umeda.
#
#  _Statistical Topological Data Analysis using Persistence Landscapes_
# Peter Bubenik  https://www.jmlr.org/papers/volume16/bubenik15a/bubenik15a.pdf
#
# _..._
